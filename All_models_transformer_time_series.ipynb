# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
import datetime as dt
from datetime import date
import argparse

import matplotlib.dates as mdates

import random

import time
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.nn import Linear

from torch.optim import Adam
from torch.utils.data import Dataset

from sklearn.model_selection import train_test_split

from tensorflow.keras.losses import MeanSquaredError
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

from numpy.random import seed
from tensorflow.random import set_seed

from keras.models import Sequential
from tensorflow import keras
from tensorflow.keras import activations
from keras.layers import Dense, Dropout, Activation, Flatten, LSTM, TimeDistributed, RepeatVector, BatchNormalization
from keras.optimizers import adam_v2
from keras.callbacks import EarlyStopping, ModelCheckpoint

import tensorflow as tf
from tensorflow import convert_to_tensor, string
from tensorflow.keras.layers import TextVectorization, Embedding, Layer

import numpy as np
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic
from statsmodels.graphics.tsaplots import plot_acf

import torch.nn as nn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
country_index = 0
country_data = ['america_cdc', 'india', 'australia'][country_index]

lack_index = 0
lack_index = ['case', 'death', 'test', 'full'][lack_index]

data_version = 1

print('Using ' + country_data + ' / lack ' + lack_index + ' data now!')
# Out:
# Using america_cdc / lack case data now!

# %% [markdown]
# # Process Data

# %% [markdown]
# ## get data

# %%
number_to_predict = 1

cdc_death = pd.read_csv('/content/drive/MyDrive/Tilburg Thesis/data/cdc_death.csv').loc[::-1,:].reset_index(drop = True).loc[:,['Date', 'New Deaths']]
cdc_case = pd.read_csv('/content/drive/MyDrive/Tilburg Thesis/data/cdc_case.csv').loc[::-1,:].reset_index(drop = True).loc[:,['Date', 'New Cases']]
cdc_test = pd.read_csv('/content/drive/MyDrive/Tilburg Thesis/data/cdc_test.csv').loc[::-1,:].reset_index(drop = True).loc[:,['Date', 'Daily Test Volume']]
cdc_dose = pd.read_csv('/content/drive/MyDrive/Tilburg Thesis/data/cdc_dose.csv').loc[:,['Date', 'Total Doses Administered Daily']].iloc[40:,:].reset_index(drop = True)
cdc_full = pd.concat([cdc_death, cdc_case, cdc_test, cdc_dose], axis = 1).dropna()


cdc_full = cdc_full.loc[:,['Date', 'New Cases', 'New Deaths', 'Daily Test Volume', 'Total Doses Administered Daily']].iloc[:,3:]
cdc_full.index = cdc_full['Date']
cdc_full = cdc_full.drop('Date', axis = 1)

cdc_full['y'] = cdc_full['Total Doses Administered Daily'].shift(-1)
cdc_full = cdc_full.dropna()



if country_data == 'america_cdc':

    cdc_lack_case = cdc_full.drop(['New Cases'], axis = 1)
    cdc_lack_death = cdc_full.drop(['New Deaths'], axis = 1)
    cdc_lack_test = cdc_full.drop(['Daily Test Volume'], axis = 1)

    if lack_index == 'full':
      cdc = cdc_full
    elif lack_index == 'case':
      cdc = cdc_lack_case
    elif lack_index == 'death':
      cdc = cdc_lack_death
    elif lack_index == 'test':
      cdc = cdc_lack_test

elif country_data == 'india':

    data_country = pd.read_csv('/content/drive/MyDrive/Tilburg Thesis/data/nation/all_data_' + country_data + '.csv', )
    data_country.index = data_country['Date']
    data_country = data_country.drop(['Date'], axis = 1)
    data_country['y'] = data_country['Doses'].shift(-1)
    data_country = data_country.dropna()
    cdc = data_country

elif country_data == 'australia':

    data_country = pd.read_csv('/content/drive/MyDrive/Tilburg Thesis/data/nation/all_data_' + country_data + '.csv', )
    data_country.index = data_country['Date']
    data_country = data_country.drop(['Date'], axis = 1)
    data_country['y'] = data_country['Doses'].shift(-1)
    data_country = data_country.dropna()
    cdc = data_country

# %% [markdown]
# ## plot

# %%
all_dates = []
d = dt.datetime(2021, 3, 2)
for i in range(422):
    all_dates.append(d)
    d = d+dt.timedelta(days=1)

train_dates = []
d = dt.datetime(2021, 3, 2)
for i in range(306):
    train_dates.append(d)
    d = d+dt.timedelta(days=1)

test_long_dates = []
d = dt.datetime(2022, 1, 1)
for i in range(90):
    test_long_dates.append(d)
    d = d+dt.timedelta(days=1)      

test_short_dates = []
d = dt.datetime(2022, 1, 1)
for i in range(31):
    test_short_dates.append(d)
    d = d+dt.timedelta(days=1)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(12,10))
ax1.plot(all_dates, cdc_full['New Cases'])
ax2.plot(all_dates, cdc_full['New Deaths'])
ax3.plot(all_dates, cdc_full['Daily Test Volume'])
ax4.plot(all_dates, cdc_full['Total Doses Administered Daily'])

#ax1.yticks(range(0,310000,100000))

ax1.ticklabel_format(style='plain', axis = 'y')
ax2.ticklabel_format(style='plain', axis = 'y')
ax3.ticklabel_format(style='plain', axis = 'y')
ax4.ticklabel_format(style='plain', axis = 'y')

ax1.vlines(dt.datetime(2022, 1, 1), 0, max(cdc_full['New Cases']) * 1.1, color="red", linestyles="dashed", linewidth=1.5)
ax2.vlines(dt.datetime(2022, 1, 1), 0, max(cdc_full['New Deaths']) * 1.1, color="red", linestyles="dashed", linewidth=1.5)
ax3.vlines(dt.datetime(2022, 1, 1), 0, max(cdc_full['Daily Test Volume']) * 1.1, color="red", linestyles="dashed", linewidth=1.5)
ax4.vlines(dt.datetime(2022, 1, 1), 0, max(cdc_full['Total Doses Administered Daily']) * 1.1, color="red", linestyles="dashed", linewidth=1.5)

ax1.grid(True)
ax2.grid(True)
ax3.grid(True)
ax4.grid(True)

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%Y'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gcf().autofmt_xdate()

ax1.set_title('Daily New Cases')
ax2.set_title('Daily New Deaths')
ax3.set_title('Daily Test')
ax4.set_title('Daily Administrated Doses')


plt.show()

# %%
def set_plot(x, y, fig, ax, color = 'blue', locator = mdates.MonthLocator(), format = '%m/%Y', subtitle = None):
    ax.plot(x, y, color = color)
    ax.ticklabel_format(style='plain', axis = 'y')
    ax.grid(True)
    ax.vlines(dt.datetime(2022, 1, 1), 0, max(y) * 1.1, color="red", linestyles="dashed", linewidth=1.5)
    ax.xaxis.set_major_formatter(mdates.DateFormatter(format))
    ax.xaxis.set_major_locator(locator)
    fig.autofmt_xdate()
    ax.set_title(subtitle)

    return ax

fig, axs = plt.subplots(4,1, figsize = (12,10))

for i, ax in enumerate(axs):
    set_plot(all_dates,
             cdc.iloc[:,i], 
             fig, 
             ax, 
             subtitle = ['Cases', 'Deaths', 'Tests', 'Doses'][i])

# %%
plot_acf(pd.read_csv('/content/drive/MyDrive/Tilburg Thesis/data/cdc_dose.csv').loc[:,['Total Doses Administered Daily']], title = None)

# %% [markdown]
# ## process data

# %%
### scale the data

from sklearn.preprocessing import StandardScaler

cdc_scaler = StandardScaler()
cdc_scaler.fit(cdc)

cdc_scaled = cdc_scaler.transform(cdc)

cdc_scaled[:5,:]
# Out:
# array([[-1.47708439, -1.68441956,  1.39052506,  1.86292661],
#        [-1.47050592, -1.6841352 ,  1.85560787,  2.17905625],
#        [-1.47379515, -1.68395641,  2.17152951,  2.20639015],
#        [-1.47269874, -1.68349496,  2.19884542,  0.96907138],
#        [-1.47379515, -1.68296369,  0.96234078, -0.23022111]])

# %%
def scale_back(y, scaler = cdc_scaler):
    length = np.array(y).size
    return scaler.inverse_transform(np.hstack((np.zeros((length,cdc.shape[1]-1)), np.array(y).reshape(-1,1))))[:,-1]
  
def mse_unscaled(y1, y2):
    return mean_squared_error(scale_back(y1), scale_back(y2))

def mape_unscaled(y1, y2):
    return mean_absolute_percentage_error(scale_back(y1), scale_back(y2))

# %% [markdown]
# ### v1

# %%
## scaled together data

if data_version == 1:
  X_ = cdc_scaled[:,:-1]
  y_ = cdc_scaled[:,-1]

  def create_sequences(X, y, seq_length):
      xs = np.zeros([len(X)-seq_length+1, seq_length, X.shape[1]])
      ys = np.zeros([len(X)-seq_length+1])

      for i in range(len(X)-seq_length+1):
          xs[i,:,:] = X[i:(i+seq_length), :]
          ys[i] = y[i+seq_length-1]

      return xs, ys

  X, y = create_sequences(X_, y_, 14)


  X_train = X[:291, :, :]
  y_train = y[:291]

  X_test_short = X[291:322, :, :]
  y_test_short = y[291:322]
  X_test_long = X[291:381, :, :]
  y_test_long = y[291:381]


  input_shape = X_train.shape[1:]
  print(X.shape)
  print(y.shape)
# Out:
# (409, 14, 3)
# (409,)

# %% [markdown]
# ### v2: scaled seperately

# %%
if data_version == 2:
  train_ = cdc.iloc[:303, :]
  test_long_ = cdc.iloc[303:393, :]
  test_short_ = cdc.iloc[303:334, :]

  train_scaler = StandardScaler()
  train_scaler.fit(train_)
  train_scaled = train_scaler.transform(train_)

  test_long_scaler = StandardScaler()
  test_long_scaler.fit(test_long_)
  test_long_scaled = test_long_scaler.transform(test_long_)

  test_short_scaler = StandardScaler()
  test_short_scaler.fit(test_short_)
  test_short_scaled = test_short_scaler.transform(test_short_)


  traintestshort = np.vstack([train_scaled, test_short_scaled])
  traintestlong = np.vstack([train_scaled, test_long_scaled])

  X_traintestshort = traintestshort[:,:-1]
  y_traintestshort = traintestshort[:,-1]
  X_traintestlong = traintestlong[:,:-1]
  y_traintestlong = traintestlong[:,-1]


  def create_sequences(X, y, seq_length):
      xs = np.zeros([len(X)-seq_length+1, seq_length, X.shape[1]])
      ys = np.zeros([len(X)-seq_length+1])

      for i in range(len(X)-seq_length+1):
          xs[i,:,:] = X[i:(i+seq_length), :]
          ys[i] = y[i+seq_length-1]

      return xs, ys

  X_traintestshort, y_traintestshort = create_sequences(X_traintestshort, y_traintestshort, 14)
  X_traintestlong, y_traintestlong = create_sequences(X_traintestlong, y_traintestlong, 14)

  X_train = X_traintestshort[:-30,:,:]
  y_train = y_traintestshort[:-30]

  X_test_short = X_traintestshort[-30:,:,:]
  y_test_short = y_traintestshort[-30:]

  X_test_long = X_traintestlong[-90:,:,:]
  y_test_long = y_traintestlong[-90:]


  input_shape = X_train.shape[1:]
  print(X_train.shape)
  print(y_train.shape)

# %% [markdown]
# ### v3: for multi transformer

# %%
if data_version == 3:
  def create_sequences_2(X, seq_length, pred_length = 3):

      dlen = len(X)-seq_length+1 - pred_length
      xs = np.zeros([dlen, seq_length, X.shape[1]])
      ys = np.zeros([dlen, pred_length, X.shape[1]])

      for i in range(dlen):
          xs[i,:,:] = X[i:(i+seq_length), :]

          ys[i,:,:] = X[i+seq_length : i+seq_length+pred_length, :]

      return xs, ys

  X_ = cdc_scaled[:,:-1]

  X, y2 = create_sequences_2(X_, 14)


  X_train = X[:291, :, :]
  y_train2 = y2[:291,:]

  X_test_short = X[291:322, :, :]
  y_test_short2 = y2[291:322,:, :]
  X_test_long = X[291:381, :, :]
  y_test_long2 = y2[291:381,:,:]


  input_shape = X_train.shape[1:]
  print(X_train.shape)
  print(y_train2.shape)

# %% [markdown]
# # Transformer Pytorch Linear decoder

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Dataset and Dataloader

# %%
class data_dataset(Dataset):
    def __init__(self, features, label):
        self.features = torch.Tensor(features)
        self.label = torch.Tensor(label)

        assert self.features.shape[0] == self.label.shape[0]

    def __len__(self):
        return self.features.shape[0]

    def __getitem__(self, i):
        return (self.features[i,...], self.label[i])


train_dataset = data_dataset(X_train, y_train)
test_dataset_long = data_dataset(X_test_long, y_test_long)
test_dataset_short = data_dataset(X_test_short, y_test_short)


train_dataloader = DataLoader(train_dataset, batch_size = 1, shuffle=True)
test_dataloader_long = DataLoader(test_dataset_long, batch_size=1, shuffle=False)
test_dataloader_short = DataLoader(test_dataset_short, batch_size=1, shuffle=False)

# %%
X_train_rmval = X_train[:-58, :, :]
X_val = X_train[-58:, :, :]
y_train_rmval = y_train[:-58]
y_val = y_train[-58:]

train_rmval_dataset = data_dataset(X_train_rmval, y_train_rmval)
val_dataset = data_dataset(X_val, y_val)

train_rmval_dataloader = DataLoader(train_rmval_dataset, batch_size = 1, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size = 1, shuffle=False)

# %% [markdown]
# ### Embeding and Positional encoding

# %%
import torch
import torch.nn as nn
import math
from torch.autograd import Variable

"""class Embedder(nn.Module):
    def __init__(self, vocab_size, d_model):
        super().__init__()
        self.d_model = d_model
        self.embed = nn.Embedding(vocab_size, d_model)
        self.conv1d = nn.Conv1d()


    def forward(self, x):
        return self.embed(x)"""

class PositionalEncoder(nn.Module):
    def __init__(self, d_model, seq_len = 14, dropout = 0.1, device = 0):
        super().__init__()
        self.d_model = d_model
        self.dropout = nn.Dropout(dropout)
        self.device = device

        pe = torch.zeros(seq_len, d_model)
        for pos in range(seq_len):
            for i in range(0, d_model, 2):
                pe[pos, i] = math.sin(pos / (10000 ** ((2 * i)/d_model)))
                if i+1 <= d_model-1:
                  pe[pos, i + 1] = math.cos(pos / (10000 ** ((2 * (i + 1))/d_model)))
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
 
    
    def forward(self, x):
        
        # make embeddings relatively larger
        # x = x * math.sqrt(self.d_model)
        
        #add constant to embedding
        # seq_len = x.size(1)
        pe = Variable(self.pe, requires_grad=False)

        if self.device != 0:
            pe.cuda()

        x = x + pe
        return self.dropout(x)

# %% [markdown]
# ### Norm and multihead

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math


class Norm(nn.Module):
    def __init__(self, d_model, eps = 1e-6):
        super().__init__()
    
        self.size = d_model
        
        # create two learnable parameters to calibrate normalisation
        self.alpha = nn.Parameter(torch.ones(self.size))
        self.bias = nn.Parameter(torch.zeros(self.size))
        
        self.eps = eps
    
    def forward(self, x):
        norm = self.alpha * (x - x.mean(dim=-1, keepdim=True)) \
        / (x.std(dim=-1, keepdim=True) + self.eps) + self.bias
        return norm

def attention(q, k, v, d_k, dropout=None):
    
    scores = torch.matmul(q, k.transpose(-2, -1)) /  math.sqrt(d_k)
    
    scores = F.softmax(scores, dim=-1)
    
    if dropout is not None:
        scores = dropout(scores)
        
    output = torch.matmul(scores, v)
    return output

class MultiHeadAttention(nn.Module):
    def __init__(self, heads, d_model, dropout = 0.1):
        super().__init__()
        
        self.d_model = d_model
        self.d_k = d_model // heads
        self.h = heads
        
        self.q_linear = nn.Linear(d_model, d_model)
        self.v_linear = nn.Linear(d_model, d_model)
        self.k_linear = nn.Linear(d_model, d_model)
        
        self.dropout = nn.Dropout(dropout)
        self.out = nn.Linear(d_model, d_model)
    
    def forward(self, q, k, v, mask=None):
        
        bs = q.size(0)
        
        # perform linear operation and split into N heads
        k = self.k_linear(k).view(bs, -1, self.h, self.d_k)
        q = self.q_linear(q).view(bs, -1, self.h, self.d_k)
        v = self.v_linear(v).view(bs, -1, self.h, self.d_k)
        
        # transpose to get dimensions bs * N * sl * d_model
        k = k.transpose(1,2)
        q = q.transpose(1,2)
        v = v.transpose(1,2)
        

        # calculate attention using function we will define next
        scores = attention(q, k, v, self.d_k, self.dropout)
        # concatenate heads and put through final linear layer
        concat = scores.transpose(1,2).contiguous()\
        .view(bs, -1, self.d_model)
        output = self.out(concat)
    
        return output

class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff=2048, dropout = 0.1):
        super().__init__() 
    
        # We set d_ff as a default to 2048
        self.linear_1 = nn.Linear(d_model, d_ff)
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(d_ff, d_model)
    
    def forward(self, x):
        x = self.dropout(F.relu(self.linear_1(x)))
        x = self.linear_2(x)
        return x

# %% [markdown]
# ### Encoder and Decoder

# %%
import torch
import torch.nn as nn

class OneEncoderLayer(nn.Module):
    def __init__(self, d_model, heads, dropout=0.1):
        super().__init__()
        self.norm_1 = Norm(d_model)
        self.norm_2 = Norm(d_model)
        self.attn = MultiHeadAttention(heads, d_model, dropout=dropout)
        self.ff = FeedForward(d_model, dropout=dropout)
        self.dropout_1 = nn.Dropout(dropout)
        self.dropout_2 = nn.Dropout(dropout)
        
    def forward(self, x):
        x = x + self.dropout_1(self.attn(x,x,x))
        x = self.norm_1(x)
        x = x + self.dropout_2(self.ff(x))
        x = self.norm_2(x)
        return x
    
# build a decoder layer with two multi-head attention layers and
# one feed-forward layer
class OneDecoderLayer(nn.Module):
    def __init__(self, decoder_outer_size, decoder_inner_size, dropout=0.1):
        super().__init__()
        self.linear_1 = Linear(decoder_outer_size, decoder_inner_size)
        self.linear_2 = Linear(decoder_inner_size, decoder_outer_size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, e_outputs):
        x = self.linear_1(e_outputs)
        x = self.dropout(F.relu(x))
        x = self.linear_2(x)
        return e_outputs + x

# %% [markdown]
# ### Build models

# %%
import torch
import torch.nn as nn 
import copy

def get_clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for i in range(N)])

class Encoder(nn.Module):
    def __init__(self, d_model, N, heads, dropout, seq_length, device = 0):
        super().__init__()
        self.N = N
        # self.embed = Embedder(vocab_size, d_model)
        self.pe = PositionalEncoder(d_model, seq_len=seq_length, dropout=dropout, device = device)
        self.layers = get_clones(OneEncoderLayer(d_model, heads, dropout), N)
        self.norm = Norm(d_model)
    def forward(self, src):
        # x = self.embed(src)
        x = self.pe(src)
        for i in range(self.N):
            x = self.layers[i](x)
        return self.norm(x)
    
class Decoder(nn.Module):
    def __init__(self, d_model, N, start_size, decoder_outer_size, decoder_inner_size, dropout):
        super().__init__()
        self.N = N
        self.start_linear = nn.Linear(start_size, decoder_outer_size)
        self.layers = get_clones(OneDecoderLayer(decoder_outer_size, decoder_inner_size, dropout), N)
        self.norm = Norm(decoder_outer_size)

    def forward(self, e_outputs):
        x = self.start_linear(e_outputs)
        for i in range(self.N):
            x = self.layers[i](x)
        return self.norm(x)

class Transformer(nn.Module):
    def __init__(self, predict_size, d_model, N_encoder, N_decoder, heads, decoder_outer_size, decoder_inner_size, inner_outsize, dropout, seq_len = 14, device = 0):
        super().__init__()
        self.encoder = Encoder(d_model, N_encoder, heads, dropout, seq_len, device)
        self.decoder = Decoder(d_model, N_decoder, d_model*seq_len, decoder_outer_size, decoder_inner_size, dropout)
        self.out_1 = nn.Linear(decoder_outer_size, inner_outsize)
        self.out_2 = nn.Linear(inner_outsize, predict_size)

    def forward(self, src):
        e_outputs = self.encoder(src)
        e_outputs = torch.flatten(e_outputs)
        d_outputs = self.decoder(e_outputs)
        output = self.out_1(d_outputs) 
        return self.out_2(output)


def get_model(settings):
    
    assert settings['d_model'] % settings['heads'] == 0
    assert settings['dropout'] < 1

    model = Transformer(settings['predict_size'], settings['d_model'],
                        settings['n_encoder_layers'], settings['n_decoder_layers'], settings['heads'], settings['decoder_outer_size'],
                        settings['decoder_inner_size'], settings['inner_outsize'], settings['dropout'], settings['seq_length'],
                        settings['device'])
       
    if settings['load_weights'] is not None:
        print("loading pretrained weights...")
        model.load_state_dict(torch.load(settings['load_weights']))
    else:
        for p in model.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p) 
    
    if settings['device'] != 0:
        model = model.cuda()
    
    return model

# %% [markdown]
# ### train function

# %%
def train_model(model, settings, train_loader, val_loader = None):

    if settings['device'] != 0:
        assert torch.cuda.is_available()
    
    print("training model...")

    start = time.time()
    if settings['checkpoint'] > 0:
        cptime = time.time()
                 
    optimizer = torch.optim.Adam(model.parameters(), lr = settings['lr'], betas=(0.9, 0.98), eps=1e-9)
    loss_function = nn.MSELoss()

    train_loss_list = []
    val_loss_list = []
    if val_loader is not None:
        y_val_list = []
        for _, y_ in val_loader:
            y_val_list.append(y_)
        y_val_list = np.array(y_val_list)

        y_train_list = []
        for _, y_ in train_loader:
            y_train_list.append(y_)
        y_train_list = np.array(y_train_list)       


    
    for epoch in range(settings['epochs']):
        model.train() # train mode

        total_loss = 0
        if settings['report']:
            print("   %dm: epoch %d [%s]  %d%%  loss = %s" % ((time.time() - start)//60, epoch + 1, "".join(' '*20), 0, '...'), end='\r')
        
        if settings['checkpoint'] > 0:
            torch.save(model.state_dict(), '/content/weights/model_weights')
                    
        for i, batch in enumerate(train_loader): 

            src = batch[0].mean(axis = 0).unsqueeze(0)  # shape (1,14,4)
            trg = batch[1].mean(axis = 0).unsqueeze(0)  # shape (1,1)

            preds = model(src)
            ys = trg.squeeze()

            optimizer.zero_grad()

            loss = F.mse_loss(preds, ys)
            loss.backward()
            optimizer.step()

            
            total_loss += loss.item()
            
            if (i + 1) % settings['print_intervals'] == 0:
                 p = int(100 * (i + 1) / len(train_loader))
                 avg_loss = total_loss / settings['print_intervals']
                 if settings['report']:
                    print("   %dm: epoch %d [%s%s]  %d%%  loss = %.3f" % ((time.time() - start)//60, epoch + 1, "".join('#'*(p//5)), "".join(' '*(20-(p//5))), p, avg_loss), end='\r')
                 else:
                    pass
                 total_loss = 0
            
            if settings['checkpoint'] > 0 and ((time.time()-cptime)//60) // settings['checkpoint'] >= 1:
                torch.save(model.state_dict(), 'weights/model_weights')
                cptime = time.time()

        if val_loader is not None:
            model.eval()
            pred_y = pred(model, val_loader)
            pred_train_y = pred(model, train_loader)

            val_loss = mean_squared_error(pred_y, y_val_list)
            val_loss_list.append(val_loss)
            print('Val Loss of epoch', epoch, 'is', val_loss)

            train_loss = mean_squared_error(pred_train_y, y_train_list)
            train_loss_list.append(train_loss)
            print('Train Loss of epoch', epoch, 'is', train_loss) 

   
   
        print("%dm: epoch %d [%s%s]  %d%%  loss = %.3f\nepoch %d complete, loss = %.03f" % ((time.time() - start)//60, epoch + 1, "".join('#'*(100//5)), "".join(' '*(20-(100//5))), 100, avg_loss, epoch + 1, avg_loss))
    
    if val_loader is not None:
        return model, np.array(train_loss_list), np.array(val_loss_list)
    else:
        return model

# %% [markdown]
# ### pred function

# %%
def pred(model, test_loader, device = 0):
    model.eval()

    pred_list = []
    sumup = 0
    for i, batch in enumerate(test_loader): 
        src = batch[0].mean(axis = 0).unsqueeze(0)  # shape (1,14,4)
        trg = batch[1].mean(axis = 0).unsqueeze(0)  # shape (1,3,4)

        preds = list(model(src).detach().numpy())
   
        pred_list.append(preds)
    
    return np.array(pred_list)

# %% [markdown]
# ## Training

# %%
result_list = []

for heads in [2,4]:
    for decoder_outer_size in [8]:
        for decoder_inner_size in [8]:
    
            setting_list = {'d_model': cdc.shape[1]-1, # data dimensions
                      'n_encoder_layers': 2,  # number of encoder
                      'n_decoder_layers': 2,  # number of decoder
                      'heads': heads,
                      'dropout': 0.1,
                      'report': True,
                      'print_intervals': 10,  # how many trains print a record
                      'checkpoint': 0,  # how many minutes save a model
                      'lr': 0.01,
                      'device': 0,
                      'predict_size': 1,  # output size
                      'seq_length': 14,
                      'load_weights': None,
                      'epochs': 200,
                      'decoder_outer_size': decoder_outer_size,  # MLP outer size
                      'decoder_inner_size': decoder_inner_size,  # MLP inner size
                      'inner_outsize': 4
                      }
            torch.manual_seed(42)
            random.seed(42)
            np.random.seed(42)

            tuning_model = get_model(setting_list)
            tuning_model = train_model(tuning_model, setting_list, train_rmval_dataloader)

            y_pred_val = pred(tuning_model, val_dataloader)
            result_mse = mean_squared_error(y_pred_val, y_val)
            result_mse_unscaled = mse_unscaled(y_pred_val, y_val)
            result_mape = mean_absolute_percentage_error(y_pred_val, y_val)
            result_mape_unscaled = mape_unscaled(y_pred_val, y_val)
            result_list.append((result_mse, result_mse_unscaled, result_mape, result_mape_unscaled, setting_list))

# %%
setting_list = {'d_model': cdc.shape[1]-1, # data dimensions
          'n_encoder_layers': 2,  # number of encoder
          'n_decoder_layers': 2,  # number of decoder
          'heads': cdc.shape[1]-1,
          'dropout': 0.1,
          'report': True,
          'print_intervals': 10,  # how many trains print a record
          'checkpoint': 0,  # how many minutes save a model
          'lr': 0.01,
          'device': 0,
          'predict_size': 1,  # output size
          'seq_length': 14,
          'load_weights': None,
          'epochs': 200,
          'decoder_outer_size': 8,  # MLP outer size
          'decoder_inner_size': 8,  # MLP inner size
          'inner_outsize': 4
          }

torch.manual_seed(42)
random.seed(42)
np.random.seed(42)

transformer_model = get_model(setting_list)

transformer_model = train_model(transformer_model, setting_list, train_dataloader)
# Out:
# training model...
#    0m: epoch 1 [                    ]  3%  loss = 1.589
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: UserWarning: Using a target size (torch.Size([])) that is different to the input size (torch.Size([1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# 0m: epoch 1 [####################]  100%  loss = 1.987
# epoch 1 complete, loss = 1.987
# 0m: epoch 2 [####################]  100%  loss = 1.434
# epoch 2 complete, loss = 1.434
# 0m: epoch 3 [####################]  100%  loss = 0.774
# epoch 3 complete, loss = 0.774
# 0m: epoch 4 [####################]  100%  loss = 1.157
# epoch 4 complete, loss = 1.157
# 0m: epoch 5 [####################]  100%  loss = 1.653
# epoch 5 complete, loss = 1.653
# 0m: epoch 6 [####################]  100%  loss = 1.215
# epoch 6 complete, loss = 1.215
# 0m: epoch 7 [####################]  100%  loss = 1.100
# epoch 7 complete, loss = 1.100
# 0m: epoch 8 [####################]  100%  loss = 0.704
# epoch 8 complete, loss = 0.704
# 0m: epoch 9 [####################]  100%  loss = 0.491
# epoch 9 complete, loss = 0.491
# 0m: epoch 10 [####################]  100%  loss = 0.402
# epoch 10 complete, loss = 0.402
# 0m: epoch 11 [####################]  100%  loss = 0.626
# epoch 11 complete, loss = 0.626
# 0m: epoch 12 [####################]  100%  loss = 0.573
# epoch 12 complete, loss = 0.573
# 0m: epoch 13 [####################]  100%  loss = 0.251
# epoch 13 complete, loss = 0.251
# 0m: epoch 14 [####################]  100%  loss = 0.499
# epoch 14 complete, loss = 0.499
# 0m: epoch 15 [####################]  100%  loss = 0.542
# epoch 15 complete, loss = 0.542
# 0m: epoch 16 [####################]  100%  loss = 0.898
# epoch 16 complete, loss = 0.898
# 0m: epoch 17 [####################]  100%  loss = 0.734
# epoch 17 complete, loss = 0.734
# 0m: epoch 18 [####################]  100%  loss = 0.270
# epoch 18 complete, loss = 0.270
# 1m: epoch 19 [####################]  100%  loss = 0.183
# epoch 19 complete, loss = 0.183
# 1m: epoch 20 [####################]  100%  loss = 0.859
# epoch 20 complete, loss = 0.859
# 1m: epoch 21 [####################]  100%  loss = 0.131
# epoch 21 complete, loss = 0.131
# 1m: epoch 22 [####################]  100%  loss = 0.559
# epoch 22 complete, loss = 0.559
# 1m: epoch 23 [####################]  100%  loss = 0.251
# epoch 23 complete, loss = 0.251
# 1m: epoch 24 [####################]  100%  loss = 0.437
# epoch 24 complete, loss = 0.437
# 1m: epoch 25 [####################]  100%  loss = 0.210
# epoch 25 complete, loss = 0.210
# 1m: epoch 26 [####################]  100%  loss = 0.535
# epoch 26 complete, loss = 0.535
# 1m: epoch 27 [####################]  100%  loss = 0.249
# epoch 27 complete, loss = 0.249
# 1m: epoch 28 [####################]  100%  loss = 0.421
# epoch 28 complete, loss = 0.421
# 1m: epoch 29 [####################]  100%  loss = 0.227
# epoch 29 complete, loss = 0.227
# 1m: epoch 30 [####################]  100%  loss = 0.347
# epoch 30 complete, loss = 0.347
# 1m: epoch 31 [####################]  100%  loss = 0.351
# epoch 31 complete, loss = 0.351
# 1m: epoch 32 [####################]  100%  loss = 0.169
# epoch 32 complete, loss = 0.169
# 1m: epoch 33 [####################]  100%  loss = 0.249
# epoch 33 complete, loss = 0.249
# 1m: epoch 34 [####################]  100%  loss = 0.513
# epoch 34 complete, loss = 0.513
# 2m: epoch 35 [####################]  100%  loss = 0.330
# epoch 35 complete, loss = 0.330
# 2m: epoch 36 [####################]  100%  loss = 1.278
# epoch 36 complete, loss = 1.278
# 2m: epoch 37 [####################]  100%  loss = 0.539
# epoch 37 complete, loss = 0.539
# 2m: epoch 38 [####################]  100%  loss = 0.175
# epoch 38 complete, loss = 0.175
# 2m: epoch 39 [####################]  100%  loss = 0.411
# epoch 39 complete, loss = 0.411
# 2m: epoch 40 [####################]  100%  loss = 0.752
# epoch 40 complete, loss = 0.752
# 2m: epoch 41 [####################]  100%  loss = 0.191
# epoch 41 complete, loss = 0.191
# 2m: epoch 42 [####################]  100%  loss = 0.641
# epoch 42 complete, loss = 0.641
# 2m: epoch 43 [####################]  100%  loss = 0.211
# epoch 43 complete, loss = 0.211
# 2m: epoch 44 [####################]  100%  loss = 0.331
# epoch 44 complete, loss = 0.331
# 2m: epoch 45 [####################]  100%  loss = 0.268
# epoch 45 complete, loss = 0.268
# 2m: epoch 46 [####################]  100%  loss = 0.602
# epoch 46 complete, loss = 0.602
# 2m: epoch 47 [####################]  100%  loss = 0.599
# epoch 47 complete, loss = 0.599
# 2m: epoch 48 [####################]  100%  loss = 0.157
# epoch 48 complete, loss = 0.157
# 2m: epoch 49 [####################]  100%  loss = 0.369
# epoch 49 complete, loss = 0.369
# 2m: epoch 50 [####################]  100%  loss = 0.205
# epoch 50 complete, loss = 0.205
# 3m: epoch 51 [####################]  100%  loss = 0.257
# epoch 51 complete, loss = 0.257
# 3m: epoch 52 [####################]  100%  loss = 0.303
# epoch 52 complete, loss = 0.303
# 3m: epoch 53 [####################]  100%  loss = 0.969
# epoch 53 complete, loss = 0.969
# 3m: epoch 54 [####################]  100%  loss = 0.355
# epoch 54 complete, loss = 0.355
# 3m: epoch 55 [####################]  100%  loss = 0.450
# epoch 55 complete, loss = 0.450
# 3m: epoch 56 [####################]  100%  loss = 0.454
# epoch 56 complete, loss = 0.454
# 3m: epoch 57 [####################]  100%  loss = 0.623
# epoch 57 complete, loss = 0.623
# 3m: epoch 58 [####################]  100%  loss = 0.634
# epoch 58 complete, loss = 0.634
# 3m: epoch 59 [####################]  100%  loss = 0.262
# epoch 59 complete, loss = 0.262
# 3m: epoch 60 [####################]  100%  loss = 0.741
# epoch 60 complete, loss = 0.741
# 3m: epoch 61 [####################]  100%  loss = 0.229
# epoch 61 complete, loss = 0.229
# 3m: epoch 62 [####################]  100%  loss = 1.419
# epoch 62 complete, loss = 1.419
# 3m: epoch 63 [####################]  100%  loss = 0.412
# epoch 63 complete, loss = 0.412
# 3m: epoch 64 [####################]  100%  loss = 0.169
# epoch 64 complete, loss = 0.169
# 3m: epoch 65 [####################]  100%  loss = 0.297
# epoch 65 complete, loss = 0.297
# 3m: epoch 66 [####################]  100%  loss = 1.027
# epoch 66 complete, loss = 1.027
# 4m: epoch 67 [####################]  100%  loss = 0.808
# epoch 67 complete, loss = 0.808
# 4m: epoch 68 [####################]  100%  loss = 0.408
# epoch 68 complete, loss = 0.408
# 4m: epoch 69 [####################]  100%  loss = 0.222
# epoch 69 complete, loss = 0.222
# 4m: epoch 70 [####################]  100%  loss = 0.403
# epoch 70 complete, loss = 0.403
# 4m: epoch 71 [####################]  100%  loss = 0.216
# epoch 71 complete, loss = 0.216
# 4m: epoch 72 [####################]  100%  loss = 0.902
# epoch 72 complete, loss = 0.902
# 4m: epoch 73 [####################]  100%  loss = 0.555
# epoch 73 complete, loss = 0.555
# 4m: epoch 74 [####################]  100%  loss = 0.297
# epoch 74 complete, loss = 0.297
# 4m: epoch 75 [####################]  100%  loss = 0.353
# epoch 75 complete, loss = 0.353
# 4m: epoch 76 [####################]  100%  loss = 0.209
# epoch 76 complete, loss = 0.209
# 4m: epoch 77 [####################]  100%  loss = 0.670
# epoch 77 complete, loss = 0.670
# 4m: epoch 78 [####################]  100%  loss = 0.366
# epoch 78 complete, loss = 0.366
# 4m: epoch 79 [####################]  100%  loss = 0.464
# epoch 79 complete, loss = 0.464
# 4m: epoch 80 [####################]  100%  loss = 0.237
# epoch 80 complete, loss = 0.237
# 4m: epoch 81 [####################]  100%  loss = 1.471
# epoch 81 complete, loss = 1.471
# 4m: epoch 82 [####################]  100%  loss = 0.612
# epoch 82 complete, loss = 0.612
# 4m: epoch 83 [####################]  100%  loss = 0.379
# epoch 83 complete, loss = 0.379
# 4m: epoch 84 [####################]  100%  loss = 0.108
# epoch 84 complete, loss = 0.108
# 4m: epoch 85 [####################]  100%  loss = 0.500
# epoch 85 complete, loss = 0.500
# 5m: epoch 86 [####################]  100%  loss = 0.323
# epoch 86 complete, loss = 0.323
# 5m: epoch 87 [####################]  100%  loss = 0.630
# epoch 87 complete, loss = 0.630
# 5m: epoch 88 [####################]  100%  loss = 0.359
# epoch 88 complete, loss = 0.359
# 5m: epoch 89 [####################]  100%  loss = 0.407
# epoch 89 complete, loss = 0.407
# 5m: epoch 90 [####################]  100%  loss = 0.714
# epoch 90 complete, loss = 0.714
# 5m: epoch 91 [####################]  100%  loss = 0.322
# epoch 91 complete, loss = 0.322
# 5m: epoch 92 [####################]  100%  loss = 0.518
# epoch 92 complete, loss = 0.518
# 5m: epoch 93 [####################]  100%  loss = 0.279
# epoch 93 complete, loss = 0.279
# 5m: epoch 94 [####################]  100%  loss = 0.508
# epoch 94 complete, loss = 0.508
# 5m: epoch 95 [####################]  100%  loss = 0.789
# epoch 95 complete, loss = 0.789
# 5m: epoch 96 [####################]  100%  loss = 0.558
# epoch 96 complete, loss = 0.558
# 5m: epoch 97 [####################]  100%  loss = 1.186
# epoch 97 complete, loss = 1.186
# 5m: epoch 98 [####################]  100%  loss = 0.388
# epoch 98 complete, loss = 0.388
# 5m: epoch 99 [####################]  100%  loss = 0.605
# epoch 99 complete, loss = 0.605
# 5m: epoch 100 [####################]  100%  loss = 1.231
# epoch 100 complete, loss = 1.231
# 5m: epoch 101 [####################]  100%  loss = 0.342
# epoch 101 complete, loss = 0.342
# 5m: epoch 102 [####################]  100%  loss = 0.850
# epoch 102 complete, loss = 0.850
# 5m: epoch 103 [####################]  100%  loss = 0.528
# epoch 103 complete, loss = 0.528
# 5m: epoch 104 [####################]  100%  loss = 0.710
# epoch 104 complete, loss = 0.710
# 6m: epoch 105 [####################]  100%  loss = 0.232
# epoch 105 complete, loss = 0.232
# 6m: epoch 106 [####################]  100%  loss = 1.084
# epoch 106 complete, loss = 1.084
# 6m: epoch 107 [####################]  100%  loss = 0.660
# epoch 107 complete, loss = 0.660
# 6m: epoch 108 [####################]  100%  loss = 0.415
# epoch 108 complete, loss = 0.415
# 6m: epoch 109 [####################]  100%  loss = 0.263
# epoch 109 complete, loss = 0.263
# 6m: epoch 110 [####################]  100%  loss = 0.614
# epoch 110 complete, loss = 0.614
# 6m: epoch 111 [####################]  100%  loss = 0.390
# epoch 111 complete, loss = 0.390
# 6m: epoch 112 [####################]  100%  loss = 0.240
# epoch 112 complete, loss = 0.240
# 6m: epoch 113 [####################]  100%  loss = 0.228
# epoch 113 complete, loss = 0.228
# 6m: epoch 114 [####################]  100%  loss = 0.287
# epoch 114 complete, loss = 0.287
# 6m: epoch 115 [####################]  100%  loss = 0.920
# epoch 115 complete, loss = 0.920
# 6m: epoch 116 [####################]  100%  loss = 0.696
# epoch 116 complete, loss = 0.696
# 6m: epoch 117 [####################]  100%  loss = 0.286
# epoch 117 complete, loss = 0.286
# 6m: epoch 118 [####################]  100%  loss = 0.668
# epoch 118 complete, loss = 0.668
# 6m: epoch 119 [####################]  100%  loss = 1.729
# epoch 119 complete, loss = 1.729
# 6m: epoch 120 [####################]  100%  loss = 1.279
# epoch 120 complete, loss = 1.279
# 6m: epoch 121 [####################]  100%  loss = 0.190
# epoch 121 complete, loss = 0.190
# 6m: epoch 122 [####################]  100%  loss = 1.609
# epoch 122 complete, loss = 1.609
# 6m: epoch 123 [####################]  100%  loss = 0.625
# epoch 123 complete, loss = 0.625
# 6m: epoch 124 [####################]  100%  loss = 1.507
# epoch 124 complete, loss = 1.507
# 7m: epoch 125 [####################]  100%  loss = 1.587
# epoch 125 complete, loss = 1.587
# 7m: epoch 126 [####################]  100%  loss = 1.229
# epoch 126 complete, loss = 1.229
# 7m: epoch 127 [####################]  100%  loss = 1.716
# epoch 127 complete, loss = 1.716
# 7m: epoch 128 [####################]  100%  loss = 1.259
# epoch 128 complete, loss = 1.259
# 7m: epoch 129 [####################]  100%  loss = 1.757
# epoch 129 complete, loss = 1.757
# 7m: epoch 130 [####################]  100%  loss = 1.018
# epoch 130 complete, loss = 1.018
# 7m: epoch 131 [####################]  100%  loss = 0.690
# epoch 131 complete, loss = 0.690
# 7m: epoch 132 [####################]  100%  loss = 0.615
# epoch 132 complete, loss = 0.615
# 7m: epoch 133 [####################]  100%  loss = 0.654
# epoch 133 complete, loss = 0.654
# 7m: epoch 134 [####################]  100%  loss = 0.578
# epoch 134 complete, loss = 0.578
# 7m: epoch 135 [####################]  100%  loss = 0.779
# epoch 135 complete, loss = 0.779
# 7m: epoch 136 [####################]  100%  loss = 1.984
# epoch 136 complete, loss = 1.984
# 7m: epoch 137 [####################]  100%  loss = 0.979
# epoch 137 complete, loss = 0.979
# 7m: epoch 138 [####################]  100%  loss = 0.250
# epoch 138 complete, loss = 0.250
# 7m: epoch 139 [####################]  100%  loss = 0.829
# epoch 139 complete, loss = 0.829
# 7m: epoch 140 [####################]  100%  loss = 1.219
# epoch 140 complete, loss = 1.219
# 7m: epoch 141 [####################]  100%  loss = 1.328
# epoch 141 complete, loss = 1.328
# 7m: epoch 142 [####################]  100%  loss = 1.277
# epoch 142 complete, loss = 1.277
# 7m: epoch 143 [####################]  100%  loss = 2.120
# epoch 143 complete, loss = 2.120
# 8m: epoch 144 [####################]  100%  loss = 0.281
# epoch 144 complete, loss = 0.281
# 8m: epoch 145 [####################]  100%  loss = 2.308
# epoch 145 complete, loss = 2.308
# 8m: epoch 146 [####################]  100%  loss = 0.949
# epoch 146 complete, loss = 0.949
# 8m: epoch 147 [####################]  100%  loss = 0.655
# epoch 147 complete, loss = 0.655
# 8m: epoch 148 [####################]  100%  loss = 0.781
# epoch 148 complete, loss = 0.781
# 8m: epoch 149 [####################]  100%  loss = 0.706
# epoch 149 complete, loss = 0.706
# 8m: epoch 150 [####################]  100%  loss = 1.197
# epoch 150 complete, loss = 1.197
# 8m: epoch 151 [####################]  100%  loss = 1.116
# epoch 151 complete, loss = 1.116
# 8m: epoch 152 [####################]  100%  loss = 1.213
# epoch 152 complete, loss = 1.213
# 8m: epoch 153 [####################]  100%  loss = 0.588
# epoch 153 complete, loss = 0.588
# 8m: epoch 154 [####################]  100%  loss = 2.554
# epoch 154 complete, loss = 2.554
# 8m: epoch 155 [####################]  100%  loss = 1.452
# epoch 155 complete, loss = 1.452
# 8m: epoch 156 [####################]  100%  loss = 0.911
# epoch 156 complete, loss = 0.911
# 8m: epoch 157 [####################]  100%  loss = 0.982
# epoch 157 complete, loss = 0.982
# 8m: epoch 158 [####################]  100%  loss = 0.974
# epoch 158 complete, loss = 0.974
# 8m: epoch 159 [####################]  100%  loss = 1.740
# epoch 159 complete, loss = 1.740
# 8m: epoch 160 [####################]  100%  loss = 0.439
# epoch 160 complete, loss = 0.439
# 8m: epoch 161 [####################]  100%  loss = 0.291
# epoch 161 complete, loss = 0.291
# 9m: epoch 162 [####################]  100%  loss = 0.256
# epoch 162 complete, loss = 0.256
# 9m: epoch 163 [####################]  100%  loss = 0.555
# epoch 163 complete, loss = 0.555
# 9m: epoch 164 [####################]  100%  loss = 0.387
# epoch 164 complete, loss = 0.387
# 9m: epoch 165 [####################]  100%  loss = 1.232
# epoch 165 complete, loss = 1.232
# 9m: epoch 166 [####################]  100%  loss = 0.661
# epoch 166 complete, loss = 0.661
# 9m: epoch 167 [####################]  100%  loss = 1.333
# epoch 167 complete, loss = 1.333
# 9m: epoch 168 [####################]  100%  loss = 2.045
# epoch 168 complete, loss = 2.045
# 9m: epoch 169 [####################]  100%  loss = 0.506
# epoch 169 complete, loss = 0.506
# 9m: epoch 170 [####################]  100%  loss = 1.679
# epoch 170 complete, loss = 1.679
# 9m: epoch 171 [####################]  100%  loss = 1.288
# epoch 171 complete, loss = 1.288
# 9m: epoch 172 [####################]  100%  loss = 0.894
# epoch 172 complete, loss = 0.894
# 9m: epoch 173 [####################]  100%  loss = 1.363
# epoch 173 complete, loss = 1.363
# 9m: epoch 174 [####################]  100%  loss = 1.387
# epoch 174 complete, loss = 1.387
# 9m: epoch 175 [####################]  100%  loss = 1.003
# epoch 175 complete, loss = 1.003
# 9m: epoch 176 [####################]  100%  loss = 0.474
# epoch 176 complete, loss = 0.474
# 9m: epoch 177 [####################]  100%  loss = 1.124
# epoch 177 complete, loss = 1.124
# 9m: epoch 178 [####################]  100%  loss = 0.200
# epoch 178 complete, loss = 0.200
# 9m: epoch 179 [####################]  100%  loss = 0.426
# epoch 179 complete, loss = 0.426
# 9m: epoch 180 [####################]  100%  loss = 0.924
# epoch 180 complete, loss = 0.924
# 10m: epoch 181 [####################]  100%  loss = 0.387
# epoch 181 complete, loss = 0.387
# 10m: epoch 182 [####################]  100%  loss = 0.349
# epoch 182 complete, loss = 0.349
# 10m: epoch 183 [####################]  100%  loss = 0.800
# epoch 183 complete, loss = 0.800
# 10m: epoch 184 [####################]  100%  loss = 1.380
# epoch 184 complete, loss = 1.380
# 10m: epoch 185 [####################]  100%  loss = 0.646
# epoch 185 complete, loss = 0.646
# 10m: epoch 186 [####################]  100%  loss = 0.430
# epoch 186 complete, loss = 0.430
# 10m: epoch 187 [####################]  100%  loss = 0.783
# epoch 187 complete, loss = 0.783
# 10m: epoch 188 [####################]  100%  loss = 0.364
# epoch 188 complete, loss = 0.364
# 10m: epoch 189 [####################]  100%  loss = 0.604
# epoch 189 complete, loss = 0.604
# 10m: epoch 190 [####################]  100%  loss = 0.183
# epoch 190 complete, loss = 0.183
# 10m: epoch 191 [####################]  100%  loss = 0.498
# epoch 191 complete, loss = 0.498
# 10m: epoch 192 [####################]  100%  loss = 0.187
# epoch 192 complete, loss = 0.187
# 10m: epoch 193 [####################]  100%  loss = 0.336
# epoch 193 complete, loss = 0.336
# 10m: epoch 194 [####################]  100%  loss = 0.596
# epoch 194 complete, loss = 0.596
# 10m: epoch 195 [####################]  100%  loss = 0.572
# epoch 195 complete, loss = 0.572
# 10m: epoch 196 [####################]  100%  loss = 0.338
# epoch 196 complete, loss = 0.338
# 10m: epoch 197 [####################]  100%  loss = 0.607
# epoch 197 complete, loss = 0.607
# 10m: epoch 198 [####################]  100%  loss = 0.737
# epoch 198 complete, loss = 0.737
# 11m: epoch 199 [####################]  100%  loss = 1.373
# epoch 199 complete, loss = 1.373
# 11m: epoch 200 [####################]  100%  loss = 0.522
# epoch 200 complete, loss = 0.522

# %% [markdown]
# ## Model save and load

# %%
### save model
if country_data == 'america_cdc':
  file_name = 'lack_' + lack_index
else:
  file_name = country_data

Path = '/content/drive/MyDrive/Tilburg Thesis/Model/' + file_name
torch.save(transformer_model, Path)

print('saved in '+ Path)
# Out:
# saved in /content/drive/MyDrive/Tilburg Thesis/Model/lack_case

# %%
### load model
if country_data == 'america_cdc':
  file_name = 'lack_' + lack_index
else:
  file_name = country_data

Path = '/content/drive/MyDrive/Tilburg Thesis/Model/' + file_name
transformer_model = torch.load(Path)
transformer_model.eval()

print('loaded from '+ Path)
# Out:
# loaded from /content/drive/MyDrive/Tilburg Thesis/Model/lack_case

# %% [markdown]
# ## Pred

# %%
transformer_y_pred_long = pred(transformer_model, test_dataloader_long)
transformer_y_pred_short = pred(transformer_model, test_dataloader_short)

unscaled_transformer_y_pred_long = scale_back(transformer_y_pred_long)
unscaled_transformer_y_test_long = scale_back(y_test_long)
unscaled_transformer_y_pred_short = scale_back(transformer_y_pred_short)
unscaled_transformer_y_test_short = scale_back(y_test_short)

# %%
plt.plot(test_long_dates, unscaled_transformer_y_pred_long, 'b--', label = 'predicted')
plt.plot(test_long_dates, unscaled_transformer_y_test_long, 'r-', label = 'actual')


plt.yticks(range(0, 2000000, 500000))
plt.ticklabel_format(style='plain', axis = 'y')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m'))
plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator())
plt.gcf().autofmt_xdate()
plt.legend()
plt.title('Prediction vs. Actual Doses in 90 Days')
plt.show()


mse_transformer_long = mse_unscaled(transformer_y_pred_long, y_test_long)
print(mse_transformer_long)
mse_transformer_long = mean_squared_error(transformer_y_pred_long, y_test_long)
print(mse_transformer_long)

mape_transformer_long = mape_unscaled(transformer_y_pred_long, y_test_long)
print(mape_transformer_long)
# Out:
# 323238102314.0569
# 0.3604091523824038
# 0.5694498892195188

# %%
import matplotlib.dates as mdates

plt.plot(test_short_dates, unscaled_transformer_y_pred_short, 'b--', label = 'predicted')
plt.plot(test_short_dates, unscaled_transformer_y_test_short, 'r-', label = 'actual')

plt.yticks(range(0, 2000000, 500000))
plt.ticklabel_format(style='plain', axis = 'y')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator())
plt.gcf().autofmt_xdate()
plt.legend()
plt.title('Prediction vs. Actual Doses in 30 Days')
plt.show()


mse_transformer_short = mse_unscaled(transformer_y_pred_short, y_test_short)
print(mse_transformer_short)

mse_transformer_short = mean_squared_error(transformer_y_pred_short, y_test_short)
print(mse_transformer_short)
mape_transformer_short = mape_unscaled(transformer_y_pred_short, y_test_short)
print(mape_transformer_short)
# Out:
# 153466225367.58173
# 0.17111420902452118
# 0.3571177880022185

# %% [markdown]
# # Transformer Pytorch Masked

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Dataset and Dataloader

# %%
class data_dataset(Dataset):
    def __init__(self, features, label):
        self.features = torch.Tensor(features)
        self.label = torch.Tensor(label)

        assert self.features.shape[0] == self.label.shape[0]

    def __len__(self):
        return self.features.shape[0]

    def __getitem__(self, i):
        return (self.features[i,...], self.label[i,...])


train_dataset = data_dataset(X_train, y_train2)
test_dataset_long = data_dataset(X_test_long, y_test_long2)
test_dataset_short = data_dataset(X_test_short, y_test_short2)

from torch.utils.data import DataLoader

train_dataloader = DataLoader(train_dataset, batch_size = 2, shuffle=True)
test_dataloader_long = DataLoader(test_dataset_long, batch_size=1, shuffle=False)
test_dataloader_short = DataLoader(test_dataset_short, batch_size=1, shuffle=False)

# %% [markdown]
# ### Embeding and Positional encoding

# %%
import torch
import torch.nn as nn
import math
from torch.autograd import Variable

"""class Embedder(nn.Module):
    def __init__(self, vocab_size, d_model):
        super().__init__()
        self.d_model = d_model
        self.embed = nn.Embedding(vocab_size, d_model)
        self.conv1d = nn.Conv1d()


    def forward(self, x):
        return self.embed(x)"""

class PositionalEncoder(nn.Module):
    def __init__(self, d_model, seq_len = 14, dropout = 0.1, device = 0):
        super().__init__()
        self.d_model = d_model
        self.dropout = nn.Dropout(dropout)
        self.device = device

        pe = torch.zeros(seq_len, d_model)
        for pos in range(seq_len):
            for i in range(0, d_model, 2):
                pe[pos, i] = math.sin(pos / (10000 ** ((2 * i)/d_model)))
                pe[pos, i + 1] = math.cos(pos / (10000 ** ((2 * (i + 1))/d_model)))
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
 
    
    def forward(self, x):
        
        # make embeddings relatively larger
        # x = x * math.sqrt(self.d_model)
        
        #add constant to embedding
        # seq_len = x.size(1)
        pe = Variable(self.pe, requires_grad=False)

        if self.device != 0:
            pe.cuda()

        x = x + pe
        return self.dropout(x)

# %% [markdown]
# ### Norm and multihead

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math


class Norm(nn.Module):
    def __init__(self, d_model, eps = 1e-6):
        super().__init__()
    
        self.size = d_model
        
        # create two learnable parameters to calibrate normalisation
        self.alpha = nn.Parameter(torch.ones(self.size))
        self.bias = nn.Parameter(torch.zeros(self.size))
        
        self.eps = eps
    
    def forward(self, x):
        norm = self.alpha * (x - x.mean(dim=-1, keepdim=True)) \
        / (x.std(dim=-1, keepdim=True) + self.eps) + self.bias
        return norm

def attention(q, k, v, d_k, mask=None, dropout=None):
    
    scores = torch.matmul(q, k.transpose(-2, -1)) /  math.sqrt(d_k)
    
    if mask is not None:
        mask = mask.unsqueeze(1)
        scores = scores.masked_fill(mask == 0, -1e9)
    
    scores = F.softmax(scores, dim=-1)
    
    if dropout is not None:
        scores = dropout(scores)
        
    output = torch.matmul(scores, v)
    return output

class MultiHeadAttention(nn.Module):
    def __init__(self, heads, d_model, dropout = 0.1):
        super().__init__()
        
        self.d_model = d_model
        self.d_k = d_model // heads
        self.h = heads
        
        self.q_linear = nn.Linear(d_model, d_model)
        self.v_linear = nn.Linear(d_model, d_model)
        self.k_linear = nn.Linear(d_model, d_model)
        
        self.dropout = nn.Dropout(dropout)
        self.out = nn.Linear(d_model, d_model)
    
    def forward(self, q, k, v, mask=None):
        
        bs = q.size(0)
        
        # perform linear operation and split into N heads
        k = self.k_linear(k).view(bs, -1, self.h, self.d_k)
        q = self.q_linear(q).view(bs, -1, self.h, self.d_k)
        v = self.v_linear(v).view(bs, -1, self.h, self.d_k)
        
        # transpose to get dimensions bs * N * sl * d_model
        k = k.transpose(1,2)
        q = q.transpose(1,2)
        v = v.transpose(1,2)
        

        # calculate attention using function we will define next
        scores = attention(q, k, v, self.d_k, mask, self.dropout)
        # concatenate heads and put through final linear layer
        concat = scores.transpose(1,2).contiguous()\
        .view(bs, -1, self.d_model)
        output = self.out(concat)
    
        return output

class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff=2048, dropout = 0.1):
        super().__init__() 
    
        # We set d_ff as a default to 2048
        self.linear_1 = nn.Linear(d_model, d_ff)
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(d_ff, d_model)
    
    def forward(self, x):
        x = self.dropout(F.relu(self.linear_1(x)))
        x = self.linear_2(x)
        return x

# %% [markdown]
# ### Encoder and Decoder

# %%
import torch
import torch.nn as nn

class OneEncoderLayer(nn.Module):
    def __init__(self, d_model, heads, dropout=0.1):
        super().__init__()
        self.norm_1 = Norm(d_model)
        self.norm_2 = Norm(d_model)
        self.attn = MultiHeadAttention(heads, d_model, dropout=dropout)
        self.ff = FeedForward(d_model, dropout=dropout)
        self.dropout_1 = nn.Dropout(dropout)
        self.dropout_2 = nn.Dropout(dropout)
        
    def forward(self, x, mask):
        x2 = self.norm_1(x)
        x = x + self.dropout_1(self.attn(x2,x2,x2,mask))
        x2 = self.norm_2(x)
        x = x + self.dropout_2(self.ff(x2))
        return x
    
# build a decoder layer with two multi-head attention layers and
# one feed-forward layer
class OneDecoderLayer(nn.Module):
    def __init__(self, d_model, heads, dropout=0.1):
        super().__init__()
        self.norm_1 = Norm(d_model)
        self.norm_2 = Norm(d_model)
        self.norm_3 = Norm(d_model)
        
        self.dropout_1 = nn.Dropout(dropout)
        self.dropout_2 = nn.Dropout(dropout)
        self.dropout_3 = nn.Dropout(dropout)
        
        self.attn_1 = MultiHeadAttention(heads, d_model, dropout=dropout)
        self.attn_2 = MultiHeadAttention(heads, d_model, dropout=dropout)
        self.ff = FeedForward(d_model, dropout=dropout)

    def forward(self, x, e_outputs, src_mask, trg_mask):
        x2 = self.norm_1(x)
        x = x + self.dropout_1(self.attn_1(x2, x2, x2, trg_mask))
        x2 = self.norm_2(x)
        x = x + self.dropout_2(self.attn_2(x2, e_outputs, e_outputs, src_mask))
        x2 = self.norm_3(x)
        x = x + self.dropout_3(self.ff(x2))
        return x

# %% [markdown]
# ### Build models

# %%
import torch
import torch.nn as nn 
import copy

def get_clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for i in range(N)])

class Encoder(nn.Module):
    def __init__(self, d_model, N, heads, dropout, seq_length, device = 0):
        super().__init__()
        self.N = N
        # self.embed = Embedder(vocab_size, d_model)
        self.pe = PositionalEncoder(d_model, seq_len=seq_length, dropout=dropout, device = device)
        self.layers = get_clones(OneEncoderLayer(d_model, heads, dropout), N)
        self.norm = Norm(d_model)
    def forward(self, src, mask):
        # x = self.embed(src)
        x = self.pe(src)
        for i in range(self.N):
            x = self.layers[i](x, mask)
        return self.norm(x)
    
class Decoder(nn.Module):
    def __init__(self, d_model, N, heads, dropout, pred_length, device = 0):
        super().__init__()
        self.N = N
        # self.embed = Embedder(vocab_size, d_model)
        self.pe = PositionalEncoder(d_model, pred_length, dropout=dropout, device = device)
        self.layers = get_clones(OneDecoderLayer(d_model, heads, dropout), N)
        self.norm = Norm(d_model)
    def forward(self, trg, e_outputs, src_mask, trg_mask):
        # x = self.embed(trg)
        x = self.pe(trg)
        for i in range(self.N):
            x = self.layers[i](x, e_outputs, src_mask, trg_mask)
        return self.norm(x)

class Transformer(nn.Module):
    def __init__(self, predict_size, d_model, N, heads, dropout, seq_len = 14, device = 0):
        super().__init__()
        self.encoder = Encoder(d_model, N, heads, dropout, seq_len, device)
        self.decoder = Decoder(d_model, N, heads, dropout, predict_size, device)
        self.out = nn.Linear(d_model, predict_size)
        self.out2 = nn.Linear(predict_size ** 2, predict_size)

    def forward(self, src, trg, src_mask, trg_mask):
        e_outputs = self.encoder(src, src_mask)
        #print("DECODER")
        d_output = self.decoder(trg, e_outputs, src_mask, trg_mask)
        output = self.out(d_output)
        output = torch.flatten(output)
        output = self.out2(output)
        return output

def get_model(settings):
    
    assert settings['d_model'] % settings['heads'] == 0
    assert settings['dropout'] < 1

    model = Transformer(settings['predict_size'], settings['d_model'], settings['n_layers'], settings['heads'], settings['dropout'], settings['seq_length'], settings['device'])
       
    if settings['load_weights'] is not None:
        print("loading pretrained weights...")
        model.load_state_dict(torch.load(settings['load_weights']))
    else:
        for p in model.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p) 
    
    if settings['device'] != 0:
        model = model.cuda()
    
    return model

# %% [markdown]
# ### Create mask

# %%
import torch
from torchtext import data
import numpy as np
from torch.autograd import Variable


def nopeak_mask(size, device = 0):
    np_mask = np.triu(np.ones((1, size, size)), k=1).astype('uint8')
    np_mask = Variable(torch.from_numpy(np_mask) == 0)
    if device != 0:
      np_mask = np_mask.cuda()
    return np_mask

def create_masks(trg, device = 0):
    
    src_mask = None # (src != settings['src_pad']).unsqueeze(-2)

    if trg is not None:
        size = trg.size(1) # get seq_len for matrix
        np_mask = nopeak_mask(size, device)
        if trg.is_cuda:
            np_mask.cuda()
        trg_mask = np_mask
        
    else:
        trg_mask = None
    return src_mask, trg_mask

# %% [markdown]
# ### Train

# %%
def train_model(model, settings, train_loader):

    if settings['device'] != 0:
        assert torch.cuda.is_available()
    
    print("training model...")
    model.train() # train mode

    start = time.time()
    if settings['checkpoint'] > 0:
        cptime = time.time()
                 
    optimizer = torch.optim.Adam(model.parameters(), lr = settings['lr'], betas=(0.9, 0.98), eps=1e-9)
    loss_function = nn.MSELoss()
    
    for epoch in range(settings['epochs']):

        total_loss = 0
        if settings['report']:
            print("   %dm: epoch %d [%s]  %d%%  loss = %s" % ((time.time() - start)//60, epoch + 1, "".join(' '*20), 0, '...'), end='\r')
        
        if settings['checkpoint'] > 0:
            torch.save(model.state_dict(), '/content/weights/model_weights')
                    
        for i, batch in enumerate(train_loader): 

            src = batch[0].mean(axis = 0).unsqueeze(0)  # shape (1,14,4)
            trg = batch[1].mean(axis = 0).unsqueeze(0)  # shape (1,3,4)

            trg_input = trg[:,:-1,:]

            src_mask, trg_mask = create_masks(trg_input, settings['device'])  # settings,device = 0 is no cuda

            src_mask = None

            preds = model(src, trg_input, src_mask, trg_mask)
            ys = trg[:, 1:, 3].squeeze()

            optimizer.zero_grad()

            loss = F.mse_loss(preds, ys)
            loss.backward()
            optimizer.step()

            
            total_loss += loss.item()
            
            if (i + 1) % settings['print_intervals'] == 0:
                 p = int(100 * (i + 1) / len(train_loader))
                 avg_loss = total_loss / settings['print_intervals']
                 if settings['report']:
                    print("   %dm: epoch %d [%s%s]  %d%%  loss = %.3f" % ((time.time() - start)//60, epoch + 1, "".join('#'*(p//5)), "".join(' '*(20-(p//5))), p, avg_loss), end='\r')
                 else:
                    pass # print("   %dm: epoch %d [%s%s]  %d%%  loss = %.3f" % ((time.time() - start)//60, epoch + 1, "".join('#'*(p//5)), "".join(' '*(20-(p//5))), p, avg_loss))
                 total_loss = 0
            
            if settings['checkpoint'] > 0 and ((time.time()-cptime)//60) // settings['checkpoint'] >= 1:
                torch.save(model.state_dict(), 'weights/model_weights')
                cptime = time.time()
   
   
        print("%dm: epoch %d [%s%s]  %d%%  loss = %.3f\nepoch %d complete, loss = %.03f" % ((time.time() - start)//60, epoch + 1, "".join('#'*(100//5)), "".join(' '*(20-(100//5))), 100, avg_loss, epoch + 1, avg_loss))
    
    return model

# %% [markdown]
# ## Trainig start

# %%
setting_list = {'d_model': 4,
          'n_layers': 2,
          'heads': 2,
          'dropout': 0.1,
          'report': True,
          'print_intervals': 10,  # how many trains print a record
          'checkpoint': 0,  # how many minutes save a model
          'lr': 0.01,
          'device': 0,
          'predict_size': 2,
          'seq_length': 14,
          'load_weights': None,
          'epochs': 200
          }

transformer_model = get_model(setting_list)
print('model setted')

model = train_model(transformer_model, setting_list, train_dataloader)

# %%
def pred(model, test_loader, device = 0):

    model.eval()

    pred_list = []

    for i, batch in enumerate(test_loader): 
        src = batch[0].mean(axis = 0).unsqueeze(0)  # shape (1,14,4)
        trg = batch[1].mean(axis = 0).unsqueeze(0)  # shape (1,3,4)
        trg_input = trg[:,:-1,:]

        src_mask, trg_mask = create_masks(trg_input, device)  # settings,device = 0 is no cuda
        src_mask = None

        preds = list(model(src, trg_input, src_mask, trg_mask).detach().numpy())

        
        if len(pred_list) == 0:
            pred_list = preds
        else:
            pred_list[-1] = (pred_list[-1] + preds[0]) * 0.5
            pred_list.append(preds[-1])
    
    return np.array(pred_list)

transformer_y_pred_long = pred(transformer_model, test_dataloader_long)[:-1]

# %%
a.shape
# Out:
# (45,)

# %%
for i, batch in enumerate(test_dataloader_long):
    print(batch[1])

# %%
transformer_y_pred_long.shape
# Out:
# (90,)

# %%
mse_unscaled(y_test_long, transformer_y_pred_long)
# Out:
# 0.5425718783020952

# %%
plt.plot(y_test_long)
plt.plot(transformer_y_pred_long)

# %% [markdown]
# # VAR Baseline

# %%
df = pd.DataFrame(cdc_scaled[:, :4])

df_train = df.iloc[:291, :]
df_test = df.iloc[291:322, :]
df_test_long = df.iloc[291:381, :]

df_differenced = df_train.diff().dropna()

# Check size
print(df_train.shape)
print(df_test.shape)
# Out:
# (291, 4)
# (31, 4)

# %% [markdown]
# ### ADF test

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")   


# ADF Test on each column
for name, column in df_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "0"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.8132
#  No. Lags Chosen       = 14
#  Critical value 1%     = -3.454
#  Critical value 5%     = -2.872
#  Critical value 10%    = -2.572
#  => P-Value = 0.0564. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "1"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.9269
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.454
#  Critical value 5%     = -2.872
#  Critical value 10%    = -2.572
#  => P-Value = 0.0423. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "2"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.3677
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.454
#  Critical value 5%     = -2.872
#  Critical value 10%    = -2.572
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "3"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.4396
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.454
#  Critical value 5%     = -2.872
#  Critical value 10%    = -2.572
#  => P-Value = 0.0003. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# ### select order

# %%
var_model = VAR(df_differenced)
x = var_model.select_order(maxlags=20)
x.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
var_model_fitted = var_model.fit(7)

lag_order = var_model_fitted.k_ar
print(lag_order)

# Input data for forecasting
forecast_input = df_differenced.values[-lag_order:]
# Out:
# 7

# %%
pred_steps = df_test.shape[0]

fc = var_model_fitted.forecast(y=forecast_input, steps = pred_steps)
df_forecast = pd.DataFrame(fc, index=df_test.index, columns=df_test.columns)


pred_steps_long = df_test_long.shape[0]

fc_long = var_model_fitted.forecast(y=forecast_input, steps = pred_steps_long)
df_forecast_long = pd.DataFrame(fc_long, index=df_test_long.index, columns=df_test_long.columns)

# %%
def invert_transformation(df_train, df_forecast, second_diff=False):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 2nd Diff
        if second_diff:
            df_fc[str(col)+'_1d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col)+'_2d'].cumsum()
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = df_train[col].iloc[-1] + df_fc.iloc[:,col].cumsum()
    return df_fc

df_results = invert_transformation(df_train, df_forecast, second_diff = False)
df_results_long = invert_transformation(df_train, df_forecast_long, second_diff = False)

# %%
plt.plot(df_results.iloc[:,7])
plt.plot(df_test.iloc[:,3])

# %%
plt.plot(df_results_long.iloc[:,7])
plt.plot(df_test_long.iloc[:,3])

# %%
mse_var_short = mean_squared_error(df_results.iloc[:,7], df_test.iloc[:,3])
print(mse_var_short)

mape_var_short = mape_unscaled(df_results.iloc[:,7], df_test.iloc[:,3])
print(mape_var_short)
# Out:
# 0.40180742933325037
# 0.3266565578163386

# %%
mse_var_long = mean_squared_error(df_results_long.iloc[:,7], df_test_long.iloc[:,3])
print(mse_var_long)

mape_var_long = mape_unscaled(df_results_long.iloc[:,7], df_test_long.iloc[:,3])
print(mape_var_long)
# Out:
# 0.8568604234471613
# 0.5763858209522742

# %% [markdown]
# # AutoRegression (not use)

# %%
df = pd.DataFrame(cdc_scaled[:, :4])

series_train = df.iloc[:291, 3]
series_test = np.array(df.iloc[291:322, 3])
series_test_long = np.array(df.iloc[291:381, 3])

series_differenced = np.array(series_train.diff().dropna())

# Check size
print(series_train.shape)
print(series_test.shape)
# Out:
# (291,)
# (31,)

# %%
from statsmodels.tsa.arima_model import ARIMA

arima_model = ARIMA(np.array(df_train.iloc[:,3]), order = (1,1,2))
arima_model_fit = arima_model.fit()
arima_model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  290
# Model:                 ARIMA(1, 1, 2)   Log Likelihood                -210.835
# Method:                       css-mle   S.D. of innovations              0.500
# Date:                Wed, 18 May 2022   AIC                            431.669
# Time:                        23:46:43   BIC                            450.019
# Sample:                             1   HQIC                           439.021
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0038      0.006     -0.668      0.505      -0.015       0.007
# ar.L1.D.y      0.0477      0.131      0.366      0.715      -0.208       0.304
# ma.L1.D.y     -0.2292      0.120     -1.905      0.058      -0.465       0.007
# ma.L2.D.y     -0.5923      0.098     -6.025      0.000      -0.785      -0.400
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           20.9548           +0.0000j           20.9548            0.0000
# MA.1            1.1202           +0.0000j            1.1202            0.0000
# MA.2           -1.5072           +0.0000j            1.5072            0.5000
# -----------------------------------------------------------------------------
# """

# %%
def arima_predict(train, test):
  history = [x for x in train]
  predictions = list()
  # walk-forward validation
  
  for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
  
  return predictions

# %%
predictions = arima_predict(series_train, series_test)

plt.plot(series_test)
plt.plot(predictions)
mse_ar_short = mse_unscaled(series_test,predictions)
mape_ar_short = mape_unscaled(series_test,predictions)

print(mse_ar_short)
print(mape_ar_short)
# Out:
# 131931901211.01656
# 2.3042689802212855

# %%
predictions_long = arima_predict(series_train, series_test_long)

plt.plot(series_test_long)
plt.plot(predictions_long)
mse_ar_long = mse_unscaled(series_test_long, predictions_long)
print(mse_ar_long)
mape_ar_long = mape_unscaled(series_test_long, predictions_long)
print(mape_ar_long)
# Out:
# 54427485087.96123
# 0.980517068450384

# %% [markdown]
# # Transformer Keras

# %% [markdown]
# ## functions

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = layers.Dropout(dropout)(x)
    
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

class PositionEmbeddingFixedWeights(Layer):
    def __init__(self, sequence_length, dimen, **kwargs):
        super(PositionEmbeddingFixedWeights, self).__init__(**kwargs)

        position_embedding_matrix = self.get_position_encoding(sequence_length, dimen)                                          

        self.position_embedding_layer = Embedding(
            input_dim=sequence_length, output_dim=dimen,
            weights=[position_embedding_matrix],
            trainable=False
        )
             
    def get_position_encoding(self, seq_len, d, n=10000):
        P = np.zeros((seq_len, d))
        for i in np.arange(int(seq_len/2)):
            for k in range(d):
                denominator = np.power(n, 2*i/d)
                P[2*i, k] = np.sin(k/denominator)
                P[2*i+1, k] = np.cos(k/denominator)
        return P

    def call(self, inputs):        
        position_indices = tf.range(tf.shape(inputs)[0])
        embedded_indices = self.position_embedding_layer(position_indices)
        return inputs + embedded_indices

  
def build_model(
    input_shape,  # shape of an X instance
    head_size,  # 
    num_heads,
    ff_dim, # number of filters
    num_transformer_blocks, # number of encoder blocks 
    mlp_units,  # number of MLP layers
    dropout=0,  #dropout rate for encoder
    mlp_dropout=0,  # dropout rate for MLP layers
):
    inputs = keras.Input(shape=input_shape)
    x = inputs

    print(x.shape)

    pe = PositionEmbeddingFixedWeights(input_shape[0], input_shape[1])
    x = pe(x)
    print(x.shape)
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(number_to_predict, activation="sigmoid")(x)
    return keras.Model(inputs, outputs)

# %% [markdown]
# ### try one

# %%
seed(42)
set_seed(42)

one_model = build_model(
    input_shape,
    head_size = 512,
    num_heads = 4,
    ff_dim = 8,
    num_transformer_blocks = 8,
    mlp_units = [128],
    mlp_dropout = 0.3,
    dropout = 0.25,
)

one_model.compile(
    loss = MeanSquaredError(),
    optimizer = keras.optimizers.Adam(learning_rate=1e-4),
    metrics = [MeanSquaredError()],
)

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

one_model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs = 200,
    batch_size = 2,
    callbacks=callbacks,
    verbose = 0
)

# %% [markdown]
# ## grid search

# %%
from pandas.core.sorting import decons_obs_group_ids
### Grid Search

head_size_list = [256, 512]
num_heads_list = [4,8]
filter_dim_list = [4,8]
num_transformer_blocks_list = [4, 6, 8]
mlp_list = [
        [128],
        [128,64,32,16],
        [128,64,32],
        [64,32],
        [32]
]
mlp_dropout_list = [0.3]
dropout_list = [0.25]


result_list = []

for head_size in head_size_list:
  for num_heads in num_heads_list:
    for ff_dim in filter_dim_list:
      for num_transformer_blocks in num_transformer_blocks_list:
        for mlp_units in mlp_list:
          for mlp_dropout in mlp_dropout_list:
            for dropout in dropout_list:

              seed(42)
              set_seed(42)
        
              model = build_model(
                        input_shape,
                        head_size = head_size,
                        num_heads = num_heads,
                        ff_dim = ff_dim,
                        num_transformer_blocks = num_transformer_blocks,
                        mlp_units = mlp_units,
                        mlp_dropout = mlp_dropout,
                        dropout = dropout,
                    )
              model.compile(
                  loss = MeanSquaredError(),
                  optimizer = keras.optimizers.Adam(learning_rate=1e-4),
                  metrics = [MeanSquaredError()],
              )

              callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

              model.fit(
                  X_train,
                  y_train,
                  validation_split=0.2,
                  epochs= 100,
                  batch_size=8,
                  callbacks=callbacks,
                  verbose = 0
              )

              result_short = model.evaluate(X_test_short, y_test_short, verbose=0)
              result_long = model.evaluate(X_test_long, y_test_long, verbose=0)

              result_list.append([head_size, num_heads, ff_dim, num_transformer_blocks, mlp_units, mlp_dropout, dropout, round(result_short[0], 4), round(result_long[0], 4)])

              print('head_size:', head_size, ' num_heads:', num_heads, ' ff_dim:', ff_dim, ' num_transformer_blocks:', num_transformer_blocks,
                    ' mlp_units:', mlp_units, ' mlp_dropout:', mlp_dropout, ' dropout:', dropout)
              
              print('Result_short:', result_short[0], ' Result_long:', result_long[0])
              print(' ')

result_list = pd.DataFrame(result_list)
result_list.columns = ['head_size', 'num_heads', 'ff_dim', 'num_transformer_blocks', 'mlp_units', 'mlp_dropout', 'dropout', 'result_short', 'result_long']
result_list

# %% [markdown]
# ### result 1

# %%
result_list1 = pd.DataFrame(result_list)
result_list1.columns = ['head_size', 'num_heads', 'ff_dim', 'num_transformer_blocks', 'mlp_units', 'mlp_dropout', 'dropout', 'result_short', 'result_long']

result_list1.to_csv('/content/drive/MyDrive/Tilburg Thesis/LSTMgridsearch1.csv')
result_list1
# Out:
#      head_size  num_heads  ff_dim  num_transformer_blocks          mlp_units  \
# 0          256          4       4                       4              [128]
# 1          256          4       4                       4  [128, 64, 32, 16]
# 2          256          4       4                       4      [128, 64, 32]
# 3          256          4       4                       4           [64, 32]
# 4          256          4       4                       4               [32]
# ..         ...        ...     ...                     ...                ...
# 115        512          8       8                       8              [128]
# 116        512          8       8                       8  [128, 64, 32, 16]
# 117        512          8       8                       8      [128, 64, 32]
# 118        512          8       8                       8           [64, 32]
# 119        512          8       8                       8               [32]
#
#      mlp_dropout  dropout  result_short  result_long
# 0            0.3     0.25        0.3586       1.0123
# 1            0.3     0.25        0.3922       1.0318
# 2            0.3     0.25        0.3772       1.0940
# 3            0.3     0.25        0.3552       1.0231
# 4            0.3     0.25        0.3512       0.9431
# ..           ...      ...           ...          ...
# 115          0.3     0.25        0.2931       0.6770
# 116          0.3     0.25        0.4253       0.8973
# 117          0.3     0.25        0.6673       1.0946
# 118          0.3     0.25        0.5316       0.9607
# 119          0.3     0.25        0.6205       1.0977
#
# [120 rows x 9 columns]

# %% [markdown]
# ### result 2

# %%
result_list2 = pd.DataFrame(result_list)
result_list2.columns = ['head_size', 'num_heads', 'ff_dim', 'num_transformer_blocks', 'mlp_units', 'mlp_dropout', 'dropout', 'result_short', 'result_long']
result_list2

# %% [markdown]
# ### result 3

# %%
result_list3 = pd.DataFrame(result_list)
result_list3.columns = ['head_size', 'num_heads', 'ff_dim', 'num_transformer_blocks', 'mlp_units', 'mlp_dropout', 'dropout', 'result_short', 'result_long']
result_list3

# %% [markdown]
# ## Get Best model

# %% [markdown]
# ### best short

# %%
best_model_short_setting = {
    'head_size': 512, 
    'num_heads': 8, 
    'ff_dim': 4,
    'num_transformer_blocks': 6,
    'mlp_units': [32],
    'mlp_dropout': 0.3,
    'dropout': 0.25
}

seed(42)
set_seed(42)

best_model_short = build_model(
    input_shape,
    head_size = best_model_short_setting['head_size'],
    num_heads = best_model_short_setting['num_heads'],
    ff_dim = best_model_short_setting['ff_dim'],
    num_transformer_blocks = best_model_short_setting['num_transformer_blocks'],
    mlp_units = best_model_short_setting['mlp_units'],
    mlp_dropout = best_model_short_setting['mlp_dropout'],
    dropout = best_model_short_setting['dropout'],
)

best_model_short.compile(
    loss = MeanSquaredError(),
    optimizer = keras.optimizers.Adam(learning_rate=1e-4),
    metrics = [MeanSquaredError()],
)

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

best_model_short.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs = 200,
    batch_size=8,
    callbacks=callbacks,
    verbose = 0
)

y_pred_short = best_model_short.predict(X_test_short)
print('MSE test for best model of short is: ', mse_unscaled(y_pred_short, y_test_short))
# Out:
# MSE test for best model of short is:  0.26923696088541144

# %%
plt.plot(y_pred_short)
plt.plot(y_test_short)

# %%
best_model_short.evaluate(X_test_short, y_test_short, verbose = 1)
# Out:
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6995 - mean_squared_error: 0.6995
# [0.6994537711143494, 0.6994537711143494]

# %% [markdown]
# ### best long

# %%
best_model_long_setting = {
    'head_size': 512, 
    'num_heads': 4, 
    'ff_dim': 8,
    'num_transformer_blocks': 8,
    'mlp_units': [128],
    'mlp_dropout': 0.3,
    'dropout': 0.25
}

seed(42)
set_seed(42)

best_model_long = build_model(
    input_shape,
    head_size = best_model_long_setting['head_size'],
    num_heads = best_model_long_setting['num_heads'],
    ff_dim = best_model_long_setting['ff_dim'],
    num_transformer_blocks = best_model_long_setting['num_transformer_blocks'],
    mlp_units = best_model_long_setting['mlp_units'],
    mlp_dropout = best_model_long_setting['mlp_dropout'],
    dropout = best_model_long_setting['dropout'],
)

best_model_long.compile(
    loss = MeanSquaredError(),
    optimizer = keras.optimizers.Adam(learning_rate=1e-4),
    metrics = [MeanSquaredError()],
)

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

best_model_long.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs = 200,
    batch_size = 2,
    callbacks=callbacks,
    verbose = 0
)

y_pred_long = best_model_long.predict(X_test_long)
print('MSE test for best model of long is: ', mse_unscaled(y_pred_long, y_test_long))
# Out:
# MSE test for best model of long is:  0.6369060312130603

# %%
plt.plot(y_pred_long)
plt.plot(y_test_long)

# %% [markdown]
# ## Save model

# %%
# save model

from google.colab import drive
drive.mount('/content/drive/')

model.save('/content/drive/MyDrive/my_model')
# Out:
# Mounted at /content/drive/
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/my_model/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/my_model/assets

# %%
from google.colab import drive
drive.mount('/content/drive/')

from tensorflow import keras
model = keras.models.load_model('/content/drive/MyDrive/my_model')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# # LSTM

# %% [markdown]
# ## functions

# %%
from tensorflow.keras.layers import Bidirectional, Conv1D, MaxPooling1D

def buildManyToOneModel(shape):
    model = Sequential()  # 别改
    model.add(LSTM(10, input_length=shape[1], input_dim=shape[2]))

    model.add(Dense(10, activation = "relu"))
    model.add(Dense(5, activation = "relu"))
    model.add(Dense(1))
    model.compile(loss="mse", optimizer="adam", metrics = ['mean_squared_error']) # 别改
    model.summary()
    return model

def buildManyToOneModel_stack(shape):
    model = Sequential()  # 别改
    model.add(LSTM(10, input_length=shape[1], input_dim=shape[2], return_sequences = True))
    model.add(LSTM(10))

    model.add(Dense(10, activation = "relu"))
    model.add(Dense(5, activation = "relu"))
    model.add(Dense(1))
    model.compile(loss="mse", optimizer="adam", metrics = ['mean_squared_error']) # 别改
    model.summary()
    return model

def buildManyToOneModel_bistack(shape):
    model = Sequential()  # 别改
    model.add(Bidirectional(LSTM(10, input_length=shape[1], input_dim=shape[2], return_sequences = True)))
    model.add(Bidirectional(LSTM(10)))

    model.add(Dense(10, activation = "relu"))
    model.add(Dense(5, activation = "relu"))
    model.add(Dense(1))
    model.compile(loss="mse", optimizer="adam", metrics = ['mean_squared_error']) # 别改
    model.build((None, shape[1], shape[2]))
    model.summary()
    return model


def buildManyToOneModel_cnnstack(shape):

    model = Sequential()

    model.add(Conv1D(3, 3, input_shape=shape[1:]))
    model.add(MaxPooling1D(2))

    model.add(LSTM(10, return_sequences = True))
    model.add(LSTM(10))

    model.add(Dense(10, activation = "relu"))
    model.add(Dense(5, activation = "relu"))
    model.add(Dense(1))
    model.compile(loss="mse", optimizer="adam", metrics = ['mean_squared_error']) # 别改
    model.summary()

    return model


def buildManyToOneModel_cnnsimple(shape):

    model = Sequential()

    model.add(Conv1D(3, 3, input_shape=shape[1:]))
    model.add(MaxPooling1D(2))

    model.add(LSTM(10))

    model.add(Dense(10, activation = "relu"))
    model.add(Dense(5, activation = "relu"))
    model.add(Dense(1))
    model.compile(loss="mse", optimizer="adam", metrics = ['mean_squared_error']) # 别改
    model.summary()

    return model

# %%
def create_sequences(X, y, seq_length):
    xs = np.zeros([len(X)-seq_length+1, seq_length, X.shape[1]])
    ys = np.zeros([len(X)-seq_length+1, seq_length])

    for i in range(len(X)-seq_length+1):
        xs[i,:,:] = X[i:(i+seq_length), :]
        ys[i,:] = y[i:(i+seq_length)]

    return xs, ys

def mda(actual: np.ndarray, predicted: np.ndarray):
    return np.mean((np.sign(actual[1:] - actual[:-1]) == np.sign(predicted[1:] - predicted[:-1])).astype(int))

def mse(actual: np.ndarray, predicted: np.ndarray):
    return np.mean(np.square(actual - predicted))

def mape(actual: np.ndarray, predicted: np.ndarray):
    return np.mean(np.abs(actual - predicted))

def rmse(actual: np.ndarray, predicted: np.ndarray):
    return np.sqrt(mse(actual, predicted))

# %% [markdown]
# ## train

# %%
X_train_lstm, X_val, y_train_lstm, y_val = train_test_split(X_train, y_train, test_size=0.10, random_state=42)


print(X_train_lstm.shape)
print(X_val.shape)

print(y_train_lstm.shape)
print(y_val.shape)


print(X_test_long.shape)
print(y_test_long.shape)

print(X_test_short.shape)
print(y_test_short.shape)
# Out:
# (261, 14, 3)
# (30, 14, 3)
# (261,)
# (30,)
# (90, 14, 3)
# (90,)
# (31, 14, 3)
# (31,)

# %%
seed(42)
set_seed(42)

model_simple_rate = buildManyToOneModel(X_train.shape)
callback = EarlyStopping(monitor="loss", patience=10, verbose=0, mode="auto")
model_simple_rate.fit(X_train, y_train, epochs=200, batch_size=8, validation_data=(X_val, y_val), callbacks=[callback])
pre_test_simple_rate_long = model_simple_rate.predict(X_test_long)
pre_test_simple_rate_short = model_simple_rate.predict(X_test_short)


seed(42)
set_seed(42)

model_stack_rate = buildManyToOneModel_stack(X_train.shape)
callback = EarlyStopping(monitor="loss", patience=10, verbose=0, mode="auto")
model_stack_rate.fit(X_train, y_train, epochs=200, batch_size=8, validation_data=(X_val, y_val), callbacks=[callback])
pre_test_stack_rate_long = model_stack_rate.predict(X_test_long)
pre_test_stack_rate_short = model_stack_rate.predict(X_test_short)


seed(42)
set_seed(42)

model_bistack_rate = buildManyToOneModel_bistack(X_train.shape)
callback = EarlyStopping(monitor="loss", patience=10, verbose=0, mode="auto")
model_bistack_rate.fit(X_train, y_train, epochs=200, batch_size=8, validation_data=(X_val, y_val), callbacks=[callback])
pre_test_bistack_rate_long = model_bistack_rate.predict(X_test_long)
pre_test_bistack_rate_short = model_bistack_rate.predict(X_test_short)


seed(42)
set_seed(42)

model_cnnstack_rate = buildManyToOneModel_cnnstack(X_train.shape)
callback = EarlyStopping(monitor="loss", patience=10, verbose=0, mode="auto")
model_cnnstack_rate.fit(X_train, y_train, epochs=200, batch_size=8, validation_data=(X_val, y_val), callbacks=[callback])
pre_test_cnnstack_rate_long = model_cnnstack_rate.predict(X_test_long)
pre_test_cnnstack_rate_short = model_cnnstack_rate.predict(X_test_short)


seed(42)
set_seed(42)

model_cnnsimple_rate = buildManyToOneModel_cnnsimple(X_train.shape)
callback = EarlyStopping(monitor="loss", patience=10, verbose=0, mode="auto")
model_cnnsimple_rate.fit(X_train, y_train, epochs=200, batch_size=8, validation_data=(X_val, y_val), callbacks=[callback])
pre_test_cnnsimple_rate_long = model_cnnsimple_rate.predict(X_test_long)
pre_test_cnnsimple_rate_short = model_cnnsimple_rate.predict(X_test_short)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10)                560
#
#  dense (Dense)               (None, 10)                110
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 731
# Trainable params: 731
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 37/37 [==============================] - 6s 26ms/step - loss: 0.9760 - mean_squared_error: 0.9760 - val_loss: 0.5722 - val_mean_squared_error: 0.5722
# Epoch 2/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.7656 - mean_squared_error: 0.7656 - val_loss: 0.4526 - val_mean_squared_error: 0.4526
# Epoch 3/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.5384 - mean_squared_error: 0.5384 - val_loss: 0.4016 - val_mean_squared_error: 0.4016
# Epoch 4/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.4028 - mean_squared_error: 0.4028 - val_loss: 0.3838 - val_mean_squared_error: 0.3838
# Epoch 5/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.3436 - mean_squared_error: 0.3436 - val_loss: 0.3920 - val_mean_squared_error: 0.3920
# Epoch 6/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.3252 - mean_squared_error: 0.3252 - val_loss: 0.3956 - val_mean_squared_error: 0.3956
# Epoch 7/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.3101 - mean_squared_error: 0.3101 - val_loss: 0.3734 - val_mean_squared_error: 0.3734
# Epoch 8/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.3067 - mean_squared_error: 0.3067 - val_loss: 0.4076 - val_mean_squared_error: 0.4076
# Epoch 9/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.2982 - mean_squared_error: 0.2982 - val_loss: 0.3805 - val_mean_squared_error: 0.3805
# Epoch 10/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.2997 - mean_squared_error: 0.2997 - val_loss: 0.3966 - val_mean_squared_error: 0.3966
# Epoch 11/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.2886 - mean_squared_error: 0.2886 - val_loss: 0.3938 - val_mean_squared_error: 0.3938
# Epoch 12/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.2779 - mean_squared_error: 0.2779 - val_loss: 0.3546 - val_mean_squared_error: 0.3546
# Epoch 13/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.2718 - mean_squared_error: 0.2718 - val_loss: 0.3801 - val_mean_squared_error: 0.3801
# Epoch 14/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.2616 - mean_squared_error: 0.2616 - val_loss: 0.3274 - val_mean_squared_error: 0.3274
# Epoch 15/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.2494 - mean_squared_error: 0.2494 - val_loss: 0.3295 - val_mean_squared_error: 0.3295
# Epoch 16/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.2378 - mean_squared_error: 0.2378 - val_loss: 0.3120 - val_mean_squared_error: 0.3120
# Epoch 17/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.2455 - mean_squared_error: 0.2455 - val_loss: 0.2918 - val_mean_squared_error: 0.2918
# Epoch 18/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.2176 - mean_squared_error: 0.2176 - val_loss: 0.2928 - val_mean_squared_error: 0.2928
# Epoch 19/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.2083 - mean_squared_error: 0.2083 - val_loss: 0.3249 - val_mean_squared_error: 0.3249
# Epoch 20/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.2052 - mean_squared_error: 0.2052 - val_loss: 0.2708 - val_mean_squared_error: 0.2708
# Epoch 21/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1971 - mean_squared_error: 0.1971 - val_loss: 0.2471 - val_mean_squared_error: 0.2471
# Epoch 22/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1932 - mean_squared_error: 0.1932 - val_loss: 0.2527 - val_mean_squared_error: 0.2527
# Epoch 23/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1757 - mean_squared_error: 0.1757 - val_loss: 0.2514 - val_mean_squared_error: 0.2514
# Epoch 24/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1616 - mean_squared_error: 0.1616 - val_loss: 0.2166 - val_mean_squared_error: 0.2166
# Epoch 25/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1522 - mean_squared_error: 0.1522 - val_loss: 0.1937 - val_mean_squared_error: 0.1937
# Epoch 26/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1469 - mean_squared_error: 0.1469 - val_loss: 0.1779 - val_mean_squared_error: 0.1779
# Epoch 27/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1463 - mean_squared_error: 0.1463 - val_loss: 0.1691 - val_mean_squared_error: 0.1691
# Epoch 28/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1374 - mean_squared_error: 0.1374 - val_loss: 0.1621 - val_mean_squared_error: 0.1621
# Epoch 29/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1324 - mean_squared_error: 0.1324 - val_loss: 0.1558 - val_mean_squared_error: 0.1558
# Epoch 30/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1292 - mean_squared_error: 0.1292 - val_loss: 0.1535 - val_mean_squared_error: 0.1535
# Epoch 31/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1270 - mean_squared_error: 0.1270 - val_loss: 0.1491 - val_mean_squared_error: 0.1491
# Epoch 32/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1227 - mean_squared_error: 0.1227 - val_loss: 0.1498 - val_mean_squared_error: 0.1498
# Epoch 33/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1189 - mean_squared_error: 0.1189 - val_loss: 0.1279 - val_mean_squared_error: 0.1279
# Epoch 34/200
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1155 - mean_squared_error: 0.1155 - val_loss: 0.1307 - val_mean_squared_error: 0.1307
# Epoch 35/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1146 - mean_squared_error: 0.1146 - val_loss: 0.1211 - val_mean_squared_error: 0.1211
# Epoch 36/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1109 - mean_squared_error: 0.1109 - val_loss: 0.1178 - val_mean_squared_error: 0.1178
# Epoch 37/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1100 - mean_squared_error: 0.1100 - val_loss: 0.1196 - val_mean_squared_error: 0.1196
# Epoch 38/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1081 - mean_squared_error: 0.1081 - val_loss: 0.1167 - val_mean_squared_error: 0.1167
# Epoch 39/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1106 - mean_squared_error: 0.1106 - val_loss: 0.1188 - val_mean_squared_error: 0.1188
# Epoch 40/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1065 - mean_squared_error: 0.1065 - val_loss: 0.0999 - val_mean_squared_error: 0.0999
# Epoch 41/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1048 - mean_squared_error: 0.1048 - val_loss: 0.1037 - val_mean_squared_error: 0.1037
# Epoch 42/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1009 - mean_squared_error: 0.1009 - val_loss: 0.1057 - val_mean_squared_error: 0.1057
# Epoch 43/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1015 - mean_squared_error: 0.1015 - val_loss: 0.1044 - val_mean_squared_error: 0.1044
# Epoch 44/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0977 - mean_squared_error: 0.0977 - val_loss: 0.1025 - val_mean_squared_error: 0.1025
# Epoch 45/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0964 - mean_squared_error: 0.0964 - val_loss: 0.0985 - val_mean_squared_error: 0.0985
# Epoch 46/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0975 - mean_squared_error: 0.0975 - val_loss: 0.0993 - val_mean_squared_error: 0.0993
# Epoch 47/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0936 - mean_squared_error: 0.0936 - val_loss: 0.0969 - val_mean_squared_error: 0.0969
# Epoch 48/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0938 - mean_squared_error: 0.0938 - val_loss: 0.0993 - val_mean_squared_error: 0.0993
# Epoch 49/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0943 - mean_squared_error: 0.0943 - val_loss: 0.0896 - val_mean_squared_error: 0.0896
# Epoch 50/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0976 - mean_squared_error: 0.0976 - val_loss: 0.1034 - val_mean_squared_error: 0.1034
# Epoch 51/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0936 - mean_squared_error: 0.0936 - val_loss: 0.0968 - val_mean_squared_error: 0.0968
# Epoch 52/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0899 - mean_squared_error: 0.0899 - val_loss: 0.0950 - val_mean_squared_error: 0.0950
# Epoch 53/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0904 - mean_squared_error: 0.0904 - val_loss: 0.0909 - val_mean_squared_error: 0.0909
# Epoch 54/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0896 - mean_squared_error: 0.0896 - val_loss: 0.1001 - val_mean_squared_error: 0.1001
# Epoch 55/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0922 - mean_squared_error: 0.0922 - val_loss: 0.0958 - val_mean_squared_error: 0.0958
# Epoch 56/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0896 - mean_squared_error: 0.0896 - val_loss: 0.0935 - val_mean_squared_error: 0.0935
# Epoch 57/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0878 - mean_squared_error: 0.0878 - val_loss: 0.0914 - val_mean_squared_error: 0.0914
# Epoch 58/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0862 - mean_squared_error: 0.0862 - val_loss: 0.0936 - val_mean_squared_error: 0.0936
# Epoch 59/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0889 - mean_squared_error: 0.0889 - val_loss: 0.1059 - val_mean_squared_error: 0.1059
# Epoch 60/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0890 - mean_squared_error: 0.0890 - val_loss: 0.0887 - val_mean_squared_error: 0.0887
# Epoch 61/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0866 - mean_squared_error: 0.0866 - val_loss: 0.0974 - val_mean_squared_error: 0.0974
# Epoch 62/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0861 - mean_squared_error: 0.0861 - val_loss: 0.0943 - val_mean_squared_error: 0.0943
# Epoch 63/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0835 - mean_squared_error: 0.0835 - val_loss: 0.1005 - val_mean_squared_error: 0.1005
# Epoch 64/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0850 - mean_squared_error: 0.0850 - val_loss: 0.1028 - val_mean_squared_error: 0.1028
# Epoch 65/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0844 - mean_squared_error: 0.0844 - val_loss: 0.1034 - val_mean_squared_error: 0.1034
# Epoch 66/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0849 - mean_squared_error: 0.0849 - val_loss: 0.0964 - val_mean_squared_error: 0.0964
# Epoch 67/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0843 - mean_squared_error: 0.0843 - val_loss: 0.0859 - val_mean_squared_error: 0.0859
# Epoch 68/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0863 - mean_squared_error: 0.0863 - val_loss: 0.0963 - val_mean_squared_error: 0.0963
# Epoch 69/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.0848 - mean_squared_error: 0.0848 - val_loss: 0.0933 - val_mean_squared_error: 0.0933
# Epoch 70/200
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0830 - mean_squared_error: 0.0830 - val_loss: 0.0898 - val_mean_squared_error: 0.0898
# Epoch 71/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0844 - mean_squared_error: 0.0844 - val_loss: 0.0960 - val_mean_squared_error: 0.0960
# Epoch 72/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0832 - mean_squared_error: 0.0832 - val_loss: 0.0972 - val_mean_squared_error: 0.0972
# Epoch 73/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0842 - mean_squared_error: 0.0842 - val_loss: 0.0928 - val_mean_squared_error: 0.0928
# Epoch 74/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0860 - mean_squared_error: 0.0860 - val_loss: 0.1041 - val_mean_squared_error: 0.1041
# Epoch 75/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0857 - mean_squared_error: 0.0857 - val_loss: 0.0872 - val_mean_squared_error: 0.0872
# Epoch 76/200
# 37/37 [==============================] - 1s 18ms/step - loss: 0.0811 - mean_squared_error: 0.0811 - val_loss: 0.1009 - val_mean_squared_error: 0.1009
# Epoch 77/200
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0819 - mean_squared_error: 0.0819 - val_loss: 0.0898 - val_mean_squared_error: 0.0898
# Epoch 78/200
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0808 - mean_squared_error: 0.0808 - val_loss: 0.0950 - val_mean_squared_error: 0.0950
# Epoch 79/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0823 - mean_squared_error: 0.0823 - val_loss: 0.0854 - val_mean_squared_error: 0.0854
# Epoch 80/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.0824 - mean_squared_error: 0.0824 - val_loss: 0.0944 - val_mean_squared_error: 0.0944
# Epoch 81/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0798 - mean_squared_error: 0.0798 - val_loss: 0.0889 - val_mean_squared_error: 0.0889
# Epoch 82/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0827 - mean_squared_error: 0.0827 - val_loss: 0.0909 - val_mean_squared_error: 0.0909
# Epoch 83/200
# 37/37 [==============================] - 1s 21ms/step - loss: 0.0793 - mean_squared_error: 0.0793 - val_loss: 0.0940 - val_mean_squared_error: 0.0940
# Epoch 84/200
# 37/37 [==============================] - 1s 21ms/step - loss: 0.0800 - mean_squared_error: 0.0800 - val_loss: 0.1031 - val_mean_squared_error: 0.1031
# Epoch 85/200
# 37/37 [==============================] - 1s 18ms/step - loss: 0.0794 - mean_squared_error: 0.0794 - val_loss: 0.0897 - val_mean_squared_error: 0.0897
# Epoch 86/200
# 37/37 [==============================] - 1s 18ms/step - loss: 0.0784 - mean_squared_error: 0.0784 - val_loss: 0.0953 - val_mean_squared_error: 0.0953
# Epoch 87/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.0790 - mean_squared_error: 0.0790 - val_loss: 0.0964 - val_mean_squared_error: 0.0964
# Epoch 88/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.0816 - mean_squared_error: 0.0816 - val_loss: 0.0906 - val_mean_squared_error: 0.0906
# Epoch 89/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0792 - mean_squared_error: 0.0792 - val_loss: 0.0857 - val_mean_squared_error: 0.0857
# Epoch 90/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0781 - mean_squared_error: 0.0781 - val_loss: 0.0960 - val_mean_squared_error: 0.0960
# Epoch 91/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.0800 - mean_squared_error: 0.0800 - val_loss: 0.0862 - val_mean_squared_error: 0.0862
# Epoch 92/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0797 - mean_squared_error: 0.0797 - val_loss: 0.0941 - val_mean_squared_error: 0.0941
# Epoch 93/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0853 - mean_squared_error: 0.0853 - val_loss: 0.0875 - val_mean_squared_error: 0.0875
# Epoch 94/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0793 - mean_squared_error: 0.0793 - val_loss: 0.0892 - val_mean_squared_error: 0.0892
# Epoch 95/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.0778 - mean_squared_error: 0.0778 - val_loss: 0.0880 - val_mean_squared_error: 0.0880
# Epoch 96/200
# 37/37 [==============================] - 1s 13ms/step - loss: 0.0766 - mean_squared_error: 0.0766 - val_loss: 0.0919 - val_mean_squared_error: 0.0919
# Epoch 97/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0771 - mean_squared_error: 0.0771 - val_loss: 0.0903 - val_mean_squared_error: 0.0903
# Epoch 98/200
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0762 - mean_squared_error: 0.0762 - val_loss: 0.0833 - val_mean_squared_error: 0.0833
# Epoch 99/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0749 - mean_squared_error: 0.0749 - val_loss: 0.0895 - val_mean_squared_error: 0.0895
# Epoch 100/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0778 - mean_squared_error: 0.0778 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 101/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0762 - mean_squared_error: 0.0762 - val_loss: 0.0850 - val_mean_squared_error: 0.0850
# Epoch 102/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0775 - mean_squared_error: 0.0775 - val_loss: 0.0962 - val_mean_squared_error: 0.0962
# Epoch 103/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0750 - mean_squared_error: 0.0750 - val_loss: 0.0826 - val_mean_squared_error: 0.0826
# Epoch 104/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0756 - mean_squared_error: 0.0756 - val_loss: 0.0963 - val_mean_squared_error: 0.0963
# Epoch 105/200
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0756 - mean_squared_error: 0.0756 - val_loss: 0.1000 - val_mean_squared_error: 0.1000
# Epoch 106/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0769 - mean_squared_error: 0.0769 - val_loss: 0.0935 - val_mean_squared_error: 0.0935
# Epoch 107/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0768 - mean_squared_error: 0.0768 - val_loss: 0.1003 - val_mean_squared_error: 0.1003
# Epoch 108/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0779 - mean_squared_error: 0.0779 - val_loss: 0.0980 - val_mean_squared_error: 0.0980
# Epoch 109/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0730 - mean_squared_error: 0.0730 - val_loss: 0.0858 - val_mean_squared_error: 0.0858
# Epoch 110/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0732 - mean_squared_error: 0.0732 - val_loss: 0.0859 - val_mean_squared_error: 0.0859
# Epoch 111/200
# 37/37 [==============================] - 1s 19ms/step - loss: 0.0744 - mean_squared_error: 0.0744 - val_loss: 0.0844 - val_mean_squared_error: 0.0844
# Epoch 112/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0770 - mean_squared_error: 0.0770 - val_loss: 0.1084 - val_mean_squared_error: 0.1084
# Epoch 113/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0766 - mean_squared_error: 0.0766 - val_loss: 0.0939 - val_mean_squared_error: 0.0939
# Epoch 114/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0751 - mean_squared_error: 0.0751 - val_loss: 0.0959 - val_mean_squared_error: 0.0959
# Epoch 115/200
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0781 - mean_squared_error: 0.0781 - val_loss: 0.0825 - val_mean_squared_error: 0.0825
# Epoch 116/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0745 - mean_squared_error: 0.0745 - val_loss: 0.0916 - val_mean_squared_error: 0.0916
# Epoch 117/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0745 - mean_squared_error: 0.0745 - val_loss: 0.0941 - val_mean_squared_error: 0.0941
# Epoch 118/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0752 - mean_squared_error: 0.0752 - val_loss: 0.0819 - val_mean_squared_error: 0.0819
# Epoch 119/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.0712 - mean_squared_error: 0.0712 - val_loss: 0.0864 - val_mean_squared_error: 0.0864
# Epoch 120/200
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0719 - mean_squared_error: 0.0719 - val_loss: 0.0871 - val_mean_squared_error: 0.0871
# Epoch 121/200
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0755 - mean_squared_error: 0.0755 - val_loss: 0.0982 - val_mean_squared_error: 0.0982
# Epoch 122/200
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0724 - mean_squared_error: 0.0724 - val_loss: 0.0830 - val_mean_squared_error: 0.0830
# Epoch 123/200
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0718 - mean_squared_error: 0.0718 - val_loss: 0.0844 - val_mean_squared_error: 0.0844
# Epoch 124/200
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0710 - mean_squared_error: 0.0710 - val_loss: 0.0827 - val_mean_squared_error: 0.0827
# Epoch 125/200
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0691 - mean_squared_error: 0.0691 - val_loss: 0.0850 - val_mean_squared_error: 0.0850
# Epoch 126/200
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0695 - mean_squared_error: 0.0695 - val_loss: 0.0787 - val_mean_squared_error: 0.0787
# Epoch 127/200
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0688 - mean_squared_error: 0.0688 - val_loss: 0.0852 - val_mean_squared_error: 0.0852
# Epoch 128/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0710 - mean_squared_error: 0.0710 - val_loss: 0.0863 - val_mean_squared_error: 0.0863
# Epoch 129/200
# 37/37 [==============================] - 1s 21ms/step - loss: 0.0694 - mean_squared_error: 0.0694 - val_loss: 0.0947 - val_mean_squared_error: 0.0947
# Epoch 130/200
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0683 - mean_squared_error: 0.0683 - val_loss: 0.0863 - val_mean_squared_error: 0.0863
# Epoch 131/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0684 - mean_squared_error: 0.0684 - val_loss: 0.0859 - val_mean_squared_error: 0.0859
# Epoch 132/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0680 - mean_squared_error: 0.0680 - val_loss: 0.0944 - val_mean_squared_error: 0.0944
# Epoch 133/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0669 - mean_squared_error: 0.0669 - val_loss: 0.0836 - val_mean_squared_error: 0.0836
# Epoch 134/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0674 - mean_squared_error: 0.0674 - val_loss: 0.0869 - val_mean_squared_error: 0.0869
# Epoch 135/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0673 - mean_squared_error: 0.0673 - val_loss: 0.0866 - val_mean_squared_error: 0.0866
# Epoch 136/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0664 - mean_squared_error: 0.0664 - val_loss: 0.0931 - val_mean_squared_error: 0.0931
# Epoch 137/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0683 - mean_squared_error: 0.0683 - val_loss: 0.0872 - val_mean_squared_error: 0.0872
# Epoch 138/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0688 - mean_squared_error: 0.0688 - val_loss: 0.0863 - val_mean_squared_error: 0.0863
# Epoch 139/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0661 - mean_squared_error: 0.0661 - val_loss: 0.0955 - val_mean_squared_error: 0.0955
# Epoch 140/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0661 - mean_squared_error: 0.0661 - val_loss: 0.0853 - val_mean_squared_error: 0.0853
# Epoch 141/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0679 - mean_squared_error: 0.0679 - val_loss: 0.0938 - val_mean_squared_error: 0.0938
# Epoch 142/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0646 - mean_squared_error: 0.0646 - val_loss: 0.0812 - val_mean_squared_error: 0.0812
# Epoch 143/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0728 - mean_squared_error: 0.0728 - val_loss: 0.0863 - val_mean_squared_error: 0.0863
# Epoch 144/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0654 - mean_squared_error: 0.0654 - val_loss: 0.0823 - val_mean_squared_error: 0.0823
# Epoch 145/200
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0709 - mean_squared_error: 0.0709 - val_loss: 0.0987 - val_mean_squared_error: 0.0987
# Epoch 146/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0652 - mean_squared_error: 0.0652 - val_loss: 0.0739 - val_mean_squared_error: 0.0739
# Epoch 147/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0718 - mean_squared_error: 0.0718 - val_loss: 0.0862 - val_mean_squared_error: 0.0862
# Epoch 148/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0659 - mean_squared_error: 0.0659 - val_loss: 0.0824 - val_mean_squared_error: 0.0824
# Epoch 149/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0675 - mean_squared_error: 0.0675 - val_loss: 0.1036 - val_mean_squared_error: 0.1036
# Epoch 150/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0637 - mean_squared_error: 0.0637 - val_loss: 0.0805 - val_mean_squared_error: 0.0805
# Epoch 151/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0635 - mean_squared_error: 0.0635 - val_loss: 0.0897 - val_mean_squared_error: 0.0897
# Epoch 152/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0625 - mean_squared_error: 0.0625 - val_loss: 0.0934 - val_mean_squared_error: 0.0934
# Epoch 153/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0616 - mean_squared_error: 0.0616 - val_loss: 0.0765 - val_mean_squared_error: 0.0765
# Epoch 154/200
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0650 - mean_squared_error: 0.0650 - val_loss: 0.0808 - val_mean_squared_error: 0.0808
# Epoch 155/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0618 - mean_squared_error: 0.0618 - val_loss: 0.0778 - val_mean_squared_error: 0.0778
# Epoch 156/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0617 - mean_squared_error: 0.0617 - val_loss: 0.0812 - val_mean_squared_error: 0.0812
# Epoch 157/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0622 - mean_squared_error: 0.0622 - val_loss: 0.0823 - val_mean_squared_error: 0.0823
# Epoch 158/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0605 - mean_squared_error: 0.0605 - val_loss: 0.0844 - val_mean_squared_error: 0.0844
# Epoch 159/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0618 - mean_squared_error: 0.0618 - val_loss: 0.0958 - val_mean_squared_error: 0.0958
# Epoch 160/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0615 - mean_squared_error: 0.0615 - val_loss: 0.0803 - val_mean_squared_error: 0.0803
# Epoch 161/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0625 - mean_squared_error: 0.0625 - val_loss: 0.0782 - val_mean_squared_error: 0.0782
# Epoch 162/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0650 - mean_squared_error: 0.0650 - val_loss: 0.0864 - val_mean_squared_error: 0.0864
# Epoch 163/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0599 - mean_squared_error: 0.0599 - val_loss: 0.0732 - val_mean_squared_error: 0.0732
# Epoch 164/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0604 - mean_squared_error: 0.0604 - val_loss: 0.0914 - val_mean_squared_error: 0.0914
# Epoch 165/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0585 - mean_squared_error: 0.0585 - val_loss: 0.0821 - val_mean_squared_error: 0.0821
# Epoch 166/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0579 - mean_squared_error: 0.0579 - val_loss: 0.0746 - val_mean_squared_error: 0.0746
# Epoch 167/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0598 - mean_squared_error: 0.0598 - val_loss: 0.0832 - val_mean_squared_error: 0.0832
# Epoch 168/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0616 - mean_squared_error: 0.0616 - val_loss: 0.0938 - val_mean_squared_error: 0.0938
# Epoch 169/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0604 - mean_squared_error: 0.0604 - val_loss: 0.0780 - val_mean_squared_error: 0.0780
# Epoch 170/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0591 - mean_squared_error: 0.0591 - val_loss: 0.0833 - val_mean_squared_error: 0.0833
# Epoch 171/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0604 - mean_squared_error: 0.0604 - val_loss: 0.1064 - val_mean_squared_error: 0.1064
# Epoch 172/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0628 - mean_squared_error: 0.0628 - val_loss: 0.0797 - val_mean_squared_error: 0.0797
# Epoch 173/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0585 - mean_squared_error: 0.0585 - val_loss: 0.0716 - val_mean_squared_error: 0.0716
# Epoch 174/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0592 - mean_squared_error: 0.0592 - val_loss: 0.0887 - val_mean_squared_error: 0.0887
# Epoch 175/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0575 - mean_squared_error: 0.0575 - val_loss: 0.0837 - val_mean_squared_error: 0.0837
# Epoch 176/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0610 - mean_squared_error: 0.0610 - val_loss: 0.0876 - val_mean_squared_error: 0.0876
# Epoch 177/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0564 - mean_squared_error: 0.0564 - val_loss: 0.0886 - val_mean_squared_error: 0.0886
# Epoch 178/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0586 - mean_squared_error: 0.0586 - val_loss: 0.0871 - val_mean_squared_error: 0.0871
# Epoch 179/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0585 - mean_squared_error: 0.0585 - val_loss: 0.0843 - val_mean_squared_error: 0.0843
# Epoch 180/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0559 - mean_squared_error: 0.0559 - val_loss: 0.0780 - val_mean_squared_error: 0.0780
# Epoch 181/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0564 - mean_squared_error: 0.0564 - val_loss: 0.0763 - val_mean_squared_error: 0.0763
# Epoch 182/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0553 - mean_squared_error: 0.0553 - val_loss: 0.0815 - val_mean_squared_error: 0.0815
# Epoch 183/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0541 - mean_squared_error: 0.0541 - val_loss: 0.0678 - val_mean_squared_error: 0.0678
# Epoch 184/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0574 - mean_squared_error: 0.0574 - val_loss: 0.0800 - val_mean_squared_error: 0.0800
# Epoch 185/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0596 - mean_squared_error: 0.0596 - val_loss: 0.0791 - val_mean_squared_error: 0.0791
# Epoch 186/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0536 - mean_squared_error: 0.0536 - val_loss: 0.0700 - val_mean_squared_error: 0.0700
# Epoch 187/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0555 - mean_squared_error: 0.0555 - val_loss: 0.0818 - val_mean_squared_error: 0.0818
# Epoch 188/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0548 - mean_squared_error: 0.0548 - val_loss: 0.0822 - val_mean_squared_error: 0.0822
# Epoch 189/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0522 - mean_squared_error: 0.0522 - val_loss: 0.0779 - val_mean_squared_error: 0.0779
# Epoch 190/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0540 - mean_squared_error: 0.0540 - val_loss: 0.0775 - val_mean_squared_error: 0.0775
# Epoch 191/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0541 - mean_squared_error: 0.0541 - val_loss: 0.0840 - val_mean_squared_error: 0.0840
# Epoch 192/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0547 - mean_squared_error: 0.0547 - val_loss: 0.0729 - val_mean_squared_error: 0.0729
# Epoch 193/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0529 - mean_squared_error: 0.0529 - val_loss: 0.0681 - val_mean_squared_error: 0.0681
# Epoch 194/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0534 - mean_squared_error: 0.0534 - val_loss: 0.0706 - val_mean_squared_error: 0.0706
# Epoch 195/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0527 - mean_squared_error: 0.0527 - val_loss: 0.0696 - val_mean_squared_error: 0.0696
# Epoch 196/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0504 - mean_squared_error: 0.0504 - val_loss: 0.0668 - val_mean_squared_error: 0.0668
# Epoch 197/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 0.0708 - val_mean_squared_error: 0.0708
# Epoch 198/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0551 - mean_squared_error: 0.0551 - val_loss: 0.0629 - val_mean_squared_error: 0.0629
# Epoch 199/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0508 - mean_squared_error: 0.0508 - val_loss: 0.0776 - val_mean_squared_error: 0.0776
# Epoch 200/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 0.0705 - val_mean_squared_error: 0.0705
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 14, 10)            560
#
#  lstm_2 (LSTM)               (None, 10)                840
#
#  dense_3 (Dense)             (None, 10)                110
#
#  dense_4 (Dense)             (None, 5)                 55
#
#  dense_5 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 1,571
# Trainable params: 1,571
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 37/37 [==============================] - 6s 46ms/step - loss: 1.0450 - mean_squared_error: 1.0450 - val_loss: 0.6284 - val_mean_squared_error: 0.6284
# Epoch 2/200
# 37/37 [==============================] - 1s 20ms/step - loss: 0.9597 - mean_squared_error: 0.9597 - val_loss: 0.5876 - val_mean_squared_error: 0.5876
# Epoch 3/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.9224 - mean_squared_error: 0.9224 - val_loss: 0.5600 - val_mean_squared_error: 0.5600
# Epoch 4/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.8981 - mean_squared_error: 0.8981 - val_loss: 0.5421 - val_mean_squared_error: 0.5421
# Epoch 5/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.8751 - mean_squared_error: 0.8751 - val_loss: 0.5240 - val_mean_squared_error: 0.5240
# Epoch 6/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.8525 - mean_squared_error: 0.8525 - val_loss: 0.5038 - val_mean_squared_error: 0.5038
# Epoch 7/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.8324 - mean_squared_error: 0.8324 - val_loss: 0.4877 - val_mean_squared_error: 0.4877
# Epoch 8/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.8149 - mean_squared_error: 0.8149 - val_loss: 0.4762 - val_mean_squared_error: 0.4762
# Epoch 9/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.7977 - mean_squared_error: 0.7977 - val_loss: 0.4626 - val_mean_squared_error: 0.4626
# Epoch 10/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.7813 - mean_squared_error: 0.7813 - val_loss: 0.4507 - val_mean_squared_error: 0.4507
# Epoch 11/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.7544 - mean_squared_error: 0.7544 - val_loss: 0.4232 - val_mean_squared_error: 0.4232
# Epoch 12/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.6654 - mean_squared_error: 0.6654 - val_loss: 0.3749 - val_mean_squared_error: 0.3749
# Epoch 13/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.4990 - mean_squared_error: 0.4990 - val_loss: 0.3903 - val_mean_squared_error: 0.3903
# Epoch 14/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.3892 - mean_squared_error: 0.3892 - val_loss: 0.3612 - val_mean_squared_error: 0.3612
# Epoch 15/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.3365 - mean_squared_error: 0.3365 - val_loss: 0.4155 - val_mean_squared_error: 0.4155
# Epoch 16/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.3156 - mean_squared_error: 0.3156 - val_loss: 0.3818 - val_mean_squared_error: 0.3818
# Epoch 17/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.3430 - mean_squared_error: 0.3430 - val_loss: 0.4196 - val_mean_squared_error: 0.4196
# Epoch 18/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.3127 - mean_squared_error: 0.3127 - val_loss: 0.4356 - val_mean_squared_error: 0.4356
# Epoch 19/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.3154 - mean_squared_error: 0.3154 - val_loss: 0.4375 - val_mean_squared_error: 0.4375
# Epoch 20/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.3092 - mean_squared_error: 0.3092 - val_loss: 0.4215 - val_mean_squared_error: 0.4215
# Epoch 21/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.3026 - mean_squared_error: 0.3026 - val_loss: 0.3952 - val_mean_squared_error: 0.3952
# Epoch 22/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.2988 - mean_squared_error: 0.2988 - val_loss: 0.4047 - val_mean_squared_error: 0.4047
# Epoch 23/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.2939 - mean_squared_error: 0.2939 - val_loss: 0.3990 - val_mean_squared_error: 0.3990
# Epoch 24/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.2806 - mean_squared_error: 0.2806 - val_loss: 0.3480 - val_mean_squared_error: 0.3480
# Epoch 25/200
# 37/37 [==============================] - 1s 18ms/step - loss: 0.2768 - mean_squared_error: 0.2768 - val_loss: 0.3749 - val_mean_squared_error: 0.3749
# Epoch 26/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.2623 - mean_squared_error: 0.2623 - val_loss: 0.3075 - val_mean_squared_error: 0.3075
# Epoch 27/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.2702 - mean_squared_error: 0.2702 - val_loss: 0.2941 - val_mean_squared_error: 0.2941
# Epoch 28/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.2439 - mean_squared_error: 0.2439 - val_loss: 0.2696 - val_mean_squared_error: 0.2696
# Epoch 29/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.2654 - mean_squared_error: 0.2654 - val_loss: 0.2641 - val_mean_squared_error: 0.2641
# Epoch 30/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.2389 - mean_squared_error: 0.2389 - val_loss: 0.2703 - val_mean_squared_error: 0.2703
# Epoch 31/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.2521 - mean_squared_error: 0.2521 - val_loss: 0.2771 - val_mean_squared_error: 0.2771
# Epoch 32/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.2374 - mean_squared_error: 0.2374 - val_loss: 0.2088 - val_mean_squared_error: 0.2088
# Epoch 33/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.2433 - mean_squared_error: 0.2433 - val_loss: 0.2161 - val_mean_squared_error: 0.2161
# Epoch 34/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.2456 - mean_squared_error: 0.2456 - val_loss: 0.2001 - val_mean_squared_error: 0.2001
# Epoch 35/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.2209 - mean_squared_error: 0.2209 - val_loss: 0.1964 - val_mean_squared_error: 0.1964
# Epoch 36/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.2140 - mean_squared_error: 0.2140 - val_loss: 0.2166 - val_mean_squared_error: 0.2166
# Epoch 37/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.2254 - mean_squared_error: 0.2254 - val_loss: 0.2126 - val_mean_squared_error: 0.2126
# Epoch 38/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.2069 - mean_squared_error: 0.2069 - val_loss: 0.1955 - val_mean_squared_error: 0.1955
# Epoch 39/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.2360 - mean_squared_error: 0.2360 - val_loss: 0.1689 - val_mean_squared_error: 0.1689
# Epoch 40/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.1953 - mean_squared_error: 0.1953 - val_loss: 0.1652 - val_mean_squared_error: 0.1652
# Epoch 41/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1902 - mean_squared_error: 0.1902 - val_loss: 0.1615 - val_mean_squared_error: 0.1615
# Epoch 42/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1924 - mean_squared_error: 0.1924 - val_loss: 0.1714 - val_mean_squared_error: 0.1714
# Epoch 43/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1872 - mean_squared_error: 0.1872 - val_loss: 0.1497 - val_mean_squared_error: 0.1497
# Epoch 44/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1815 - mean_squared_error: 0.1815 - val_loss: 0.1597 - val_mean_squared_error: 0.1597
# Epoch 45/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1823 - mean_squared_error: 0.1823 - val_loss: 0.1272 - val_mean_squared_error: 0.1272
# Epoch 46/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1775 - mean_squared_error: 0.1775 - val_loss: 0.1330 - val_mean_squared_error: 0.1330
# Epoch 47/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1767 - mean_squared_error: 0.1767 - val_loss: 0.1359 - val_mean_squared_error: 0.1359
# Epoch 48/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.1762 - mean_squared_error: 0.1762 - val_loss: 0.1420 - val_mean_squared_error: 0.1420
# Epoch 49/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.1772 - mean_squared_error: 0.1772 - val_loss: 0.1365 - val_mean_squared_error: 0.1365
# Epoch 50/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1699 - mean_squared_error: 0.1699 - val_loss: 0.1405 - val_mean_squared_error: 0.1405
# Epoch 51/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1685 - mean_squared_error: 0.1685 - val_loss: 0.1380 - val_mean_squared_error: 0.1380
# Epoch 52/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.1724 - mean_squared_error: 0.1724 - val_loss: 0.1170 - val_mean_squared_error: 0.1170
# Epoch 53/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.1639 - mean_squared_error: 0.1639 - val_loss: 0.1302 - val_mean_squared_error: 0.1302
# Epoch 54/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1669 - mean_squared_error: 0.1669 - val_loss: 0.1275 - val_mean_squared_error: 0.1275
# Epoch 55/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1673 - mean_squared_error: 0.1673 - val_loss: 0.1257 - val_mean_squared_error: 0.1257
# Epoch 56/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.1642 - mean_squared_error: 0.1642 - val_loss: 0.1208 - val_mean_squared_error: 0.1208
# Epoch 57/200
# 37/37 [==============================] - 1s 18ms/step - loss: 0.1560 - mean_squared_error: 0.1560 - val_loss: 0.1135 - val_mean_squared_error: 0.1135
# Epoch 58/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.1564 - mean_squared_error: 0.1564 - val_loss: 0.1241 - val_mean_squared_error: 0.1241
# Epoch 59/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1619 - mean_squared_error: 0.1619 - val_loss: 0.1341 - val_mean_squared_error: 0.1341
# Epoch 60/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1544 - mean_squared_error: 0.1544 - val_loss: 0.1075 - val_mean_squared_error: 0.1075
# Epoch 61/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1484 - mean_squared_error: 0.1484 - val_loss: 0.1159 - val_mean_squared_error: 0.1159
# Epoch 62/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.1625 - mean_squared_error: 0.1625 - val_loss: 0.1284 - val_mean_squared_error: 0.1284
# Epoch 63/200
# 37/37 [==============================] - 1s 15ms/step - loss: 0.1554 - mean_squared_error: 0.1554 - val_loss: 0.1188 - val_mean_squared_error: 0.1188
# Epoch 64/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.1510 - mean_squared_error: 0.1510 - val_loss: 0.1347 - val_mean_squared_error: 0.1347
# Epoch 65/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1420 - mean_squared_error: 0.1420 - val_loss: 0.1072 - val_mean_squared_error: 0.1072
# Epoch 66/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1422 - mean_squared_error: 0.1422 - val_loss: 0.0984 - val_mean_squared_error: 0.0984
# Epoch 67/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1431 - mean_squared_error: 0.1431 - val_loss: 0.1172 - val_mean_squared_error: 0.1172
# Epoch 68/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.1380 - mean_squared_error: 0.1380 - val_loss: 0.1135 - val_mean_squared_error: 0.1135
# Epoch 69/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.1327 - mean_squared_error: 0.1327 - val_loss: 0.1003 - val_mean_squared_error: 0.1003
# Epoch 70/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1371 - mean_squared_error: 0.1371 - val_loss: 0.0962 - val_mean_squared_error: 0.0962
# Epoch 71/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1395 - mean_squared_error: 0.1395 - val_loss: 0.1270 - val_mean_squared_error: 0.1270
# Epoch 72/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1291 - mean_squared_error: 0.1291 - val_loss: 0.0995 - val_mean_squared_error: 0.0995
# Epoch 73/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1250 - mean_squared_error: 0.1250 - val_loss: 0.1230 - val_mean_squared_error: 0.1230
# Epoch 74/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.1343 - mean_squared_error: 0.1343 - val_loss: 0.0945 - val_mean_squared_error: 0.0945
# Epoch 75/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1280 - mean_squared_error: 0.1280 - val_loss: 0.1044 - val_mean_squared_error: 0.1044
# Epoch 76/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1303 - mean_squared_error: 0.1303 - val_loss: 0.1093 - val_mean_squared_error: 0.1093
# Epoch 77/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1286 - mean_squared_error: 0.1286 - val_loss: 0.0863 - val_mean_squared_error: 0.0863
# Epoch 78/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1268 - mean_squared_error: 0.1268 - val_loss: 0.1125 - val_mean_squared_error: 0.1125
# Epoch 79/200
# 37/37 [==============================] - 1s 17ms/step - loss: 0.1202 - mean_squared_error: 0.1202 - val_loss: 0.0779 - val_mean_squared_error: 0.0779
# Epoch 80/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1216 - mean_squared_error: 0.1216 - val_loss: 0.0895 - val_mean_squared_error: 0.0895
# Epoch 81/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1167 - mean_squared_error: 0.1167 - val_loss: 0.0855 - val_mean_squared_error: 0.0855
# Epoch 82/200
# 37/37 [==============================] - 1s 16ms/step - loss: 0.1145 - mean_squared_error: 0.1145 - val_loss: 0.1085 - val_mean_squared_error: 0.1085
# Epoch 83/200
# ...
# Epoch 103/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1297 - mean_squared_error: 0.1297 - val_loss: 0.0947 - val_mean_squared_error: 0.0947
# Epoch 104/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1280 - mean_squared_error: 0.1280 - val_loss: 0.0977 - val_mean_squared_error: 0.0977
# Epoch 105/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1338 - mean_squared_error: 0.1338 - val_loss: 0.0992 - val_mean_squared_error: 0.0992
# Epoch 106/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1315 - mean_squared_error: 0.1315 - val_loss: 0.1146 - val_mean_squared_error: 0.1146
# Epoch 107/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1280 - mean_squared_error: 0.1280 - val_loss: 0.0953 - val_mean_squared_error: 0.0953
# Epoch 108/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1269 - mean_squared_error: 0.1269 - val_loss: 0.1111 - val_mean_squared_error: 0.1111
# Epoch 109/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1383 - mean_squared_error: 0.1383 - val_loss: 0.0937 - val_mean_squared_error: 0.0937
# Epoch 110/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1315 - mean_squared_error: 0.1315 - val_loss: 0.0945 - val_mean_squared_error: 0.0945
# Epoch 111/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1236 - mean_squared_error: 0.1236 - val_loss: 0.0935 - val_mean_squared_error: 0.0935
# Epoch 112/200
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1190 - mean_squared_error: 0.1190 - val_loss: 0.0970 - val_mean_squared_error: 0.0970
# Epoch 113/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.1174 - mean_squared_error: 0.1174 - val_loss: 0.0942 - val_mean_squared_error: 0.0942
# Epoch 114/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.1169 - mean_squared_error: 0.1169 - val_loss: 0.1009 - val_mean_squared_error: 0.1009
# Epoch 115/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1229 - mean_squared_error: 0.1229 - val_loss: 0.0830 - val_mean_squared_error: 0.0830
# Epoch 116/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1249 - mean_squared_error: 0.1249 - val_loss: 0.1030 - val_mean_squared_error: 0.1030
# Epoch 117/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1244 - mean_squared_error: 0.1244 - val_loss: 0.1079 - val_mean_squared_error: 0.1079
# Epoch 118/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.1218 - mean_squared_error: 0.1218 - val_loss: 0.0944 - val_mean_squared_error: 0.0944
# Epoch 119/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.1174 - mean_squared_error: 0.1174 - val_loss: 0.0938 - val_mean_squared_error: 0.0938
# Epoch 120/200
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1141 - mean_squared_error: 0.1141 - val_loss: 0.0928 - val_mean_squared_error: 0.0928
# Epoch 121/200
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1181 - mean_squared_error: 0.1181 - val_loss: 0.1046 - val_mean_squared_error: 0.1046
# Epoch 122/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1151 - mean_squared_error: 0.1151 - val_loss: 0.0845 - val_mean_squared_error: 0.0845
# Epoch 123/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1095 - mean_squared_error: 0.1095 - val_loss: 0.0883 - val_mean_squared_error: 0.0883
# Epoch 124/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1075 - mean_squared_error: 0.1075 - val_loss: 0.0994 - val_mean_squared_error: 0.0994
# Epoch 125/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.1194 - mean_squared_error: 0.1194 - val_loss: 0.0863 - val_mean_squared_error: 0.0863
# Epoch 126/200
# 37/37 [==============================] - 0s 11ms/step - loss: 0.1180 - mean_squared_error: 0.1180 - val_loss: 0.0913 - val_mean_squared_error: 0.0913
# Epoch 127/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1121 - mean_squared_error: 0.1121 - val_loss: 0.0923 - val_mean_squared_error: 0.0923
# Epoch 128/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1194 - mean_squared_error: 0.1194 - val_loss: 0.0735 - val_mean_squared_error: 0.0735
# Epoch 129/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1092 - mean_squared_error: 0.1092 - val_loss: 0.0953 - val_mean_squared_error: 0.0953
# Epoch 130/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1119 - mean_squared_error: 0.1119 - val_loss: 0.0940 - val_mean_squared_error: 0.0940
# Epoch 131/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1097 - mean_squared_error: 0.1097 - val_loss: 0.0816 - val_mean_squared_error: 0.0816
# Epoch 132/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1053 - mean_squared_error: 0.1053 - val_loss: 0.0887 - val_mean_squared_error: 0.0887
# Epoch 133/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1135 - mean_squared_error: 0.1135 - val_loss: 0.0876 - val_mean_squared_error: 0.0876
# Epoch 134/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1039 - mean_squared_error: 0.1039 - val_loss: 0.0854 - val_mean_squared_error: 0.0854
# Epoch 135/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1005 - mean_squared_error: 0.1005 - val_loss: 0.0877 - val_mean_squared_error: 0.0877
# Epoch 136/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1070 - mean_squared_error: 0.1070 - val_loss: 0.0998 - val_mean_squared_error: 0.0998
# Epoch 137/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1038 - mean_squared_error: 0.1038 - val_loss: 0.0795 - val_mean_squared_error: 0.0795
# Epoch 138/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1028 - mean_squared_error: 0.1028 - val_loss: 0.0945 - val_mean_squared_error: 0.0945
# Epoch 139/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1037 - mean_squared_error: 0.1037 - val_loss: 0.0786 - val_mean_squared_error: 0.0786
# Epoch 140/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1015 - mean_squared_error: 0.1015 - val_loss: 0.0788 - val_mean_squared_error: 0.0788
# Epoch 141/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1030 - mean_squared_error: 0.1030 - val_loss: 0.0783 - val_mean_squared_error: 0.0783
# Epoch 142/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1003 - mean_squared_error: 0.1003 - val_loss: 0.0850 - val_mean_squared_error: 0.0850
# Epoch 143/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1012 - mean_squared_error: 0.1012 - val_loss: 0.0691 - val_mean_squared_error: 0.0691
# Epoch 144/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0989 - mean_squared_error: 0.0989 - val_loss: 0.0762 - val_mean_squared_error: 0.0762
# Epoch 145/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0928 - mean_squared_error: 0.0928 - val_loss: 0.1180 - val_mean_squared_error: 0.1180
# Epoch 146/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1013 - mean_squared_error: 0.1013 - val_loss: 0.0770 - val_mean_squared_error: 0.0770
# Epoch 147/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.0793 - val_mean_squared_error: 0.0793
# Epoch 148/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0961 - mean_squared_error: 0.0961 - val_loss: 0.0738 - val_mean_squared_error: 0.0738
# Epoch 149/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0994 - mean_squared_error: 0.0994 - val_loss: 0.0807 - val_mean_squared_error: 0.0807
# Epoch 150/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0900 - mean_squared_error: 0.0900 - val_loss: 0.0715 - val_mean_squared_error: 0.0715
# Epoch 151/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0888 - mean_squared_error: 0.0888 - val_loss: 0.0723 - val_mean_squared_error: 0.0723
# Epoch 152/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0897 - mean_squared_error: 0.0897 - val_loss: 0.0859 - val_mean_squared_error: 0.0859
# Epoch 153/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0916 - mean_squared_error: 0.0916 - val_loss: 0.0688 - val_mean_squared_error: 0.0688
# Epoch 154/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0867 - mean_squared_error: 0.0867 - val_loss: 0.0643 - val_mean_squared_error: 0.0643
# Epoch 155/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0886 - mean_squared_error: 0.0886 - val_loss: 0.0670 - val_mean_squared_error: 0.0670
# Epoch 156/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0885 - mean_squared_error: 0.0885 - val_loss: 0.0592 - val_mean_squared_error: 0.0592
# Epoch 157/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0853 - mean_squared_error: 0.0853 - val_loss: 0.0793 - val_mean_squared_error: 0.0793
# Epoch 158/200
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0839 - mean_squared_error: 0.0839 - val_loss: 0.0717 - val_mean_squared_error: 0.0717
# Epoch 159/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0843 - mean_squared_error: 0.0843 - val_loss: 0.0837 - val_mean_squared_error: 0.0837
# Epoch 160/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0874 - mean_squared_error: 0.0874 - val_loss: 0.0917 - val_mean_squared_error: 0.0917
# Epoch 161/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0834 - mean_squared_error: 0.0834 - val_loss: 0.0543 - val_mean_squared_error: 0.0543
# Epoch 162/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0778 - mean_squared_error: 0.0778 - val_loss: 0.0706 - val_mean_squared_error: 0.0706
# Epoch 163/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0841 - mean_squared_error: 0.0841 - val_loss: 0.0574 - val_mean_squared_error: 0.0574
# Epoch 164/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0782 - mean_squared_error: 0.0782 - val_loss: 0.0606 - val_mean_squared_error: 0.0606
# Epoch 165/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0763 - mean_squared_error: 0.0763 - val_loss: 0.0557 - val_mean_squared_error: 0.0557
# Epoch 166/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0746 - mean_squared_error: 0.0746 - val_loss: 0.0474 - val_mean_squared_error: 0.0474
# Epoch 167/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0749 - mean_squared_error: 0.0749 - val_loss: 0.0590 - val_mean_squared_error: 0.0590
# Epoch 168/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0752 - mean_squared_error: 0.0752 - val_loss: 0.0418 - val_mean_squared_error: 0.0418
# Epoch 169/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0835 - mean_squared_error: 0.0835 - val_loss: 0.0589 - val_mean_squared_error: 0.0589
# Epoch 170/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0736 - mean_squared_error: 0.0736 - val_loss: 0.0457 - val_mean_squared_error: 0.0457
# Epoch 171/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0754 - mean_squared_error: 0.0754 - val_loss: 0.0516 - val_mean_squared_error: 0.0516
# Epoch 172/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0680 - mean_squared_error: 0.0680 - val_loss: 0.0836 - val_mean_squared_error: 0.0836
# Epoch 173/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0819 - mean_squared_error: 0.0819 - val_loss: 0.0399 - val_mean_squared_error: 0.0399
# Epoch 174/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0717 - mean_squared_error: 0.0717 - val_loss: 0.0450 - val_mean_squared_error: 0.0450
# Epoch 175/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0720 - mean_squared_error: 0.0720 - val_loss: 0.0604 - val_mean_squared_error: 0.0604
# Epoch 176/200
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0689 - mean_squared_error: 0.0689 - val_loss: 0.0471 - val_mean_squared_error: 0.0471
# Epoch 177/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0673 - mean_squared_error: 0.0673 - val_loss: 0.0448 - val_mean_squared_error: 0.0448
# Epoch 178/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0674 - mean_squared_error: 0.0674 - val_loss: 0.0461 - val_mean_squared_error: 0.0461
# Epoch 179/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0661 - mean_squared_error: 0.0661 - val_loss: 0.0419 - val_mean_squared_error: 0.0419
# Epoch 180/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0670 - mean_squared_error: 0.0670 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 181/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0746 - mean_squared_error: 0.0746 - val_loss: 0.0551 - val_mean_squared_error: 0.0551
# Epoch 182/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0674 - mean_squared_error: 0.0674 - val_loss: 0.0382 - val_mean_squared_error: 0.0382
# Epoch 183/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0626 - mean_squared_error: 0.0626 - val_loss: 0.0356 - val_mean_squared_error: 0.0356
# Epoch 184/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0632 - mean_squared_error: 0.0632 - val_loss: 0.0354 - val_mean_squared_error: 0.0354
# Epoch 185/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0645 - mean_squared_error: 0.0645 - val_loss: 0.0357 - val_mean_squared_error: 0.0357
# Epoch 186/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0624 - mean_squared_error: 0.0624 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
# Epoch 187/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0692 - mean_squared_error: 0.0692 - val_loss: 0.0463 - val_mean_squared_error: 0.0463
# Epoch 188/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0654 - mean_squared_error: 0.0654 - val_loss: 0.0575 - val_mean_squared_error: 0.0575
# Epoch 189/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0616 - mean_squared_error: 0.0616 - val_loss: 0.0354 - val_mean_squared_error: 0.0354
# Epoch 190/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0612 - mean_squared_error: 0.0612 - val_loss: 0.0341 - val_mean_squared_error: 0.0341
# Epoch 191/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0587 - mean_squared_error: 0.0587 - val_loss: 0.0422 - val_mean_squared_error: 0.0422
# Epoch 192/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0623 - mean_squared_error: 0.0623 - val_loss: 0.0320 - val_mean_squared_error: 0.0320
# Epoch 193/200
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0576 - mean_squared_error: 0.0576 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 194/200
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0634 - mean_squared_error: 0.0634 - val_loss: 0.0342 - val_mean_squared_error: 0.0342
# Epoch 195/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0588 - mean_squared_error: 0.0588 - val_loss: 0.0347 - val_mean_squared_error: 0.0347
# Epoch 196/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0660 - mean_squared_error: 0.0660 - val_loss: 0.0546 - val_mean_squared_error: 0.0546
# Epoch 197/200
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0623 - mean_squared_error: 0.0623 - val_loss: 0.0438 - val_mean_squared_error: 0.0438
# Epoch 198/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0586 - mean_squared_error: 0.0586 - val_loss: 0.0339 - val_mean_squared_error: 0.0339
# Epoch 199/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0667 - mean_squared_error: 0.0667 - val_loss: 0.0438 - val_mean_squared_error: 0.0438
# Epoch 200/200
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0643 - mean_squared_error: 0.0643 - val_loss: 0.0397 - val_mean_squared_error: 0.0397

# %% [markdown]
# ## predict

# %%
mse_lstm_stack_long = mean_squared_error(pre_test_stack_rate_long, y_test_long)
print(mse_lstm_stack_long)

mape_lstm_stack_long = mape_unscaled(pre_test_stack_rate_long, y_test_long)
print(mape_lstm_stack_long)

mse_lstm_stack_short = mean_squared_error(pre_test_stack_rate_short, y_test_short)
print(mse_lstm_stack_short)

mape_lstm_stack_short = mape_unscaled(pre_test_stack_rate_short, y_test_short)
print(mape_lstm_stack_short)
# Out:
# 0.5782450777654133
# 0.8376990914484354
# 0.36857473610512215
# 1.1562249007797496

# %%
plt.figure(figsize=(12,6))
plt.ticklabel_format(style='plain', axis = 'y')

plt.plot(test_long_dates, scale_back(pre_test_stack_rate_long), 'y--', label = 'stacked LSTM', alpha = 0.85)
plt.plot(test_long_dates, scale_back(pre_test_simple_rate_long), 'g--', label = 'single LSTM', alpha = 0.7)
plt.plot(test_long_dates, scale_back(pre_test_cnnsimple_rate_long), 'b--', label = 'CNN-LSTM', alpha = 0.7)
plt.plot(test_long_dates, scale_back(pre_test_bistack_rate_long), '--', color = 'purple', label = 'Bi-LSTM', alpha = 0.7)

plt.plot(test_long_dates, scale_back(y_test_long), 'r-', label = 'actual', linewidth = 2)

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m'))
plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator())
plt.gcf().autofmt_xdate()

plt.grid()
plt.title('Predictions of Different LSTM Variants & Actual Doses in 90 Days')
plt.legend()

# %%
mse_lstm_simple_short = mean_squared_error(pre_test_simple_rate_short, y_test_short)
print(mse_lstm_simple_short)

mape_lstm_simple_short = mape_unscaled(pre_test_simple_rate_short, y_test_short)
print(mape_lstm_simple_short)

mse_lstm_simple_long = mean_squared_error(pre_test_simple_rate_long, y_test_long)
print(mse_lstm_simple_long)

mape_lstm_simple_long = mape_unscaled(pre_test_simple_rate_long, y_test_long)
print(mape_lstm_simple_long)
# Out:
# 0.1280119713123996
# 0.3757124576490579
# 0.458433540710593
# 0.5553770329395682

# %%
plt.plot(pre_test_bistack_rate_long, 'b-')
plt.plot(y_test_long, 'g-')

# %%
mse_lstm_bistack_long = mean_squared_error(pre_test_bistack_rate_long, y_test_long)
print(mse_lstm_bistack_long)

mape_lstm_bistack_long = mape_unscaled(pre_test_bistack_rate_long, y_test_long)
print(mape_lstm_bistack_long)

mse_lstm_bistack_short = mean_squared_error(pre_test_bistack_rate_short, y_test_short)
print(mse_lstm_bistack_short)

mape_lstm_bistack_short = mape_unscaled(pre_test_bistack_rate_short, y_test_short)
print(mape_lstm_bistack_short)
# Out:
# 0.2239956641999469
# 0.8864390324965014
# 0.37569665985784434
# 1.5331759330100743

# %%
plt.plot(pre_test_cnnstack_rate_long, 'b-')
plt.plot(y_test_long, 'g-')

# %%
mse_lstm_cnnstack_long = mean_squared_error(pre_test_cnnstack_rate_long, y_test_long)
print(mse_lstm_cnnstack_long)

mape_lstm_cnnstack_long = mape_unscaled(pre_test_cnnstack_rate_long, y_test_long)
print(mape_lstm_cnnstack_long)

mse_lstm_cnnstack_short = mean_squared_error(pre_test_cnnstack_rate_short, y_test_short)
print(mse_lstm_cnnstack_short)

mape_lstm_cnnstack_short = mape_unscaled(pre_test_cnnstack_rate_short, y_test_short)
print(mape_lstm_cnnstack_short)
# Out:
# 1.3432767409392667
# 0.672227384597326
# 0.4388037707378957
# 0.40241727720476794

# %%
mse_lstm_cnnsimple_long = mean_squared_error(pre_test_cnnsimple_rate_long, y_test_long)
print(mse_lstm_cnnsimple_long)

mape_lstm_cnnsimple_long = mape_unscaled(pre_test_cnnsimple_rate_long, y_test_long)
print(mape_lstm_cnnsimple_long)

mse_lstm_cnnsimple_short = mean_squared_error(pre_test_cnnsimple_rate_short, y_test_short)
print(mse_lstm_cnnsimple_short)

mape_lstm_cnnsimple_short = mape_unscaled(pre_test_cnnsimple_rate_short, y_test_short)
print(mape_lstm_cnnsimple_short)
# Out:
# 1.1031001220359384
# 0.6496847786904142
# 0.6134051184195471
# 0.41851912036915956

# %% [markdown]
# # Results

# %%
# ar_results = np.array([mse_ar_short, mse_ar_long, mape_ar_short, mape_ar_long])
var_results = np.array([mse_var_short, mse_var_long, mape_var_short, mape_var_long])
lstm_stack_results = np.array([mse_lstm_stack_short, mse_lstm_stack_long, mape_lstm_stack_short, mape_lstm_stack_long])
lstm_simple_results = np.array([mse_lstm_simple_short, mse_lstm_simple_long, mape_lstm_simple_short, mape_lstm_simple_long])
lstm_bistack_results = np.array([mse_lstm_bistack_short, mse_lstm_bistack_long, mape_lstm_bistack_short, mape_lstm_bistack_long])
lstm_cnnsimple_results = np.array([mse_lstm_cnnsimple_short, mse_lstm_cnnsimple_long, mape_lstm_cnnsimple_short, mape_lstm_cnnsimple_long])
transformer_results = np.array([mse_transformer_short, mse_transformer_long, mape_transformer_short, mape_transformer_long])


results = np.vstack([
            var_results,
            lstm_stack_results, 
            lstm_simple_results, 
            lstm_bistack_results, 
            lstm_cnnsimple_results,
            transformer_results
            ])
row_index = [ 'VAR', 'LSTM_stack', 'LSTM_simple', 'LSTM_bistack', 'LSTM_cnnsimple', 'Transformer']
results = pd.DataFrame(results, index = row_index)
results.columns = ['MSE_short', 'MSE_long', 'MAPE_short', 'MAPE_long']
results
# Out:
#                 MSE_short  MSE_long  MAPE_short  MAPE_long
# VAR              0.401807  0.856860    0.326657   0.576386
# LSTM_stack       0.273140  0.202841    0.732903   0.587512
# LSTM_simple      0.128012  0.458434    0.375712   0.555377
# LSTM_bistack     0.375697  0.223996    1.533176   0.886439
# LSTM_cnnsimple   0.613405  1.103100    0.418519   0.649685
# Transformer      0.104732  0.055617    0.236921   0.322017
